# %% [markdown]
# <a href="https://colab.research.google.com/github/AliHertz701/django_project/blob/main/Train_TFLite2_Object_Detction_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TensorFlow Lite Object Detection API in Colab
# **Author:** Evan Juras, [EJ Technology Consultants](https://ejtech.io)
#
# **Last updated:** 1/28/23
#
# **GitHub:** [TensorFlow Lite Object Detection](https://github.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi)
#
# # Introduction
#
# This notebook uses [the TensorFlow 2 Object Detection API](https://github.com/tensorflow/models/tree/master/research/object_detection) to train an SSD-MobileNet model or EfficientDet model with a custom dataset and convert it to TensorFlow Lite format. By working through this Colab, you'll be able to create and download a TFLite model that you can run on your PC, an Android phone, or an edge device like the Raspberry Pi.
#
# <p align=center>
# <img src="https://s3.us-west-1.amazonaws.com/evanjuras.com/img/CoinDetectorDemo.gif" height="360"><br>
# <i>Custom SSD-MobileNet-FPNLite model in action!</i>
# </p>
#
# I also made a YouTube video that walks through this guide step by step. I use a coin detection model as an example for the video. I recommend following along with the video while working through this notebook.
#
# <p align=center>
# <a href="https://www.youtube.com/watch?v=XZ7FYAMCc4M" target="_blank"><img src="https://s3.us-west-1.amazonaws.com/evanjuras.com/img/thumbnail-tflite-colab-1.png" height="240"><br>
# <i>Click here to go to the video!</i></a>
# </p>
#
# **Important note: This notebook will be continuously updated to make sure it works with newer versions of TensorFlow. If you see any differences between the YouTube video and this notebook, always follow the notebook!**
#
# ### Working in Colab
# Colab provides a virtual machine in your browser complete with a Linux OS, filesystem, Python environment, and best of all, a free GPU. It comes with most TensorFlow backend requirements (like CUDA and cuDNN) pre-installed. Simply click the play button on sections of code in this notebook to execute them on the virtual machine.
#
# > *Note: Make sure you're using a GPU-equipped machine by going to "Runtime" -> "Change runtime type" in the top menu bar, and then selecting "GPU" from the Hardware accelerator dropdown.*
#
# This Colab notebook uses TensorFlow 2. If you'd like to use TensorFlow 1, please see my [TF1 Colab notebook](https://colab.research.google.com/github/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/blob/master/Train_TFLite1_Object_Detection_Model.ipynb).
#
# ### Navigation
# This is a long notebook! Each step of the training process has its own section. Click the arrow next to the heading for each section to expand it. You can use the table of contents in the left sidebar to jump from section to section.

# %% [markdown]
# # 1.&nbsp;Gather and Label Training Images

# %% [markdown]
# Before we start training, we need to gather and label images that will be used for training the object detection model. A good starting point for a proof-of-concept model is 200 images. The training images should have random objects in the image along with the desired objects, and should have a variety of backgrounds and lighting conditions.
#
# Watch the YouTube video below for instructions and tips on how to gather and label images for training an object detection model.
#
# <p align=center>
# <a href="https://www.youtube.com/watch?v=v0ssiOY6cfg" target="_blank"><img src="https://s3.us-west-1.amazonaws.com/evanjuras.com/img/thumbnail-capture-label-data.png" height="240"><br>
# <i>Watch this video to learn how to capture and label images.</i></a>
# </p>
#
# When you've finished gathering and labeling images, you should have a folder full of images and corresponding .xml data annotation file for each image. An example of a labeled image and the image folder for my coin detector model are shown below.
#
# ![](https://raw.githubusercontent.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/master/doc/labeled_image_example2.png)

# %% [markdown]
# #2.&nbsp;Install TensorFlow Object Detection Dependencies

# %% [markdown]
# First, we'll install the TensorFlow Object Detection API in this Google Colab instance. This requires cloning the [TensorFlow models repository](https://github.com/tensorflow/models) and running a couple installation commands. Click the play button to run the following sections of code.
#
# The latest version of TensorFlow this Colab has been verified to work with is TF v2.8.0.

# %%
# Clone the tensorflow models repository from GitHub
# !pip uninstall Cython -y # Temporary fix for "No module named 'object_detection'" error
# !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Found existing installation: Cython 3.0.11
# Uninstalling Cython-3.0.11:
#   Successfully uninstalled Cython-3.0.11
# Cloning into 'models'...
# remote: Enumerating objects: 4305, done.
# remote: Counting objects: 100% (4305/4305), done.
# remote: Compressing objects: 100% (3324/3324), done.
# remote: Total 4305 (delta 1207), reused 2096 (delta 908), pack-reused 0 (from 0)
# Receiving objects: 100% (4305/4305), 53.17 MiB | 28.67 MiB/s, done.
# Resolving deltas: 100% (1207/1207), done.

# %%
# Copy setup files into models/research folder
# %%bash
cd models/research/
protoc object_detection/protos/*.proto --python_out=.
#cp object_detection/packages/tf2/setup.py .

# %%
# Modify setup.py file to install the tf-models-official repository targeted at TF v2.8.0
import re
with open('/content/models/research/object_detection/packages/tf2/setup.py') as f:
    s = f.read()

with open('/content/models/research/setup.py', 'w') as f:
    # Set fine_tune_checkpoint path
    s = re.sub('tf-models-official>=2.5.1',
               'tf-models-official==2.8.0', s)
    f.write(s)

# %%
# Install the Object Detection API (NOTE: This block takes about 10 minutes to finish executing)

# Need to do a temporary fix with PyYAML because Colab isn't able to install PyYAML v5.4.1
# !pip install pyyaml==5.3
# !pip install /content/models/research/

# Need to downgrade to TF v2.8.0 due to Colab compatibility bug with TF v2.10 (as of 10/03/22)
# !pip install tensorflow==2.8.0

# Install CUDA version 11.0 (to maintain compatibility with TF v2.8.0)
# !pip install tensorflow_io==0.23.1
# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# !mv cuda-ubuntu1804.pin /etc/apt/preferences.d/cuda-repository-pin-600
# !wget http://developer.download.nvidia.com/compute/cuda/11.0.2/local_installers/cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb
# !dpkg -i cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb
# !apt-key add /var/cuda-repo-ubuntu1804-11-0-local/7fa2af80.pub
# !apt-get update && sudo apt-get install cuda-toolkit-11-0
# !export LD_LIBRARY_PATH=/usr/local/cuda-11.0/lib64:$LD_LIBRARY_PATH
# Out:
# Requirement already satisfied: pyyaml==5.3 in /usr/local/lib/python3.10/dist-packages (5.3)
# Processing ./models/research
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: avro-python3 in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (1.10.2)
# Requirement already satisfied: apache-beam in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (2.61.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (11.0.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (5.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (3.8.0)
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (3.0.11)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (21.6.0)
# Requirement already satisfied: tf-slim in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (1.17.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (2.0.8)
# Requirement already satisfied: lvis in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (1.13.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (2.2.2)
# Requirement already satisfied: tf-models-official==2.8.0 in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (2.8.0)
# Requirement already satisfied: tensorflow_io in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (0.23.1)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (2.8.0)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (2.4.7)
# Requirement already satisfied: sacrebleu<=2.2.0 in /usr/local/lib/python3.10/dist-packages (from object_detection==0.1) (2.2.0)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (2.155.0)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (1.6.17)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (1.26.4)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (4.10.0.84)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (5.9.5)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (9.0.0)
# Requirement already satisfied: pyyaml<6.0,>=5.1 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (5.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (0.2.0)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (1.2.2)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (0.23.0)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (4.9.7)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (0.16.1)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (0.8.0)
# Requirement already satisfied: tensorflow-text~=2.8.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (2.8.2)
# Requirement already satisfied: tensorflow~=2.8.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object_detection==0.1) (2.8.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->object_detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->object_detection==0.1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->object_detection==0.1) (2024.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object_detection==0.1) (3.0.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object_detection==0.1) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object_detection==0.1) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object_detection==0.1) (0.4.6)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf-slim->object_detection==0.1) (1.4.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (1.7)
# Requirement already satisfied: orjson<4,>=3.9.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (3.10.12)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (1.10.0)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (0.19)
# Requirement already satisfied: grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<1.66.0,<2,>=1.33.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (1.65.5)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (0.22.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (4.23.0)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (3.4.2)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (0.7.0)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (24.2)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (4.10.1)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (1.25.0)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<6.0.0.dev0,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (4.25.5)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (1.4.2)
# Requirement already satisfied: redis<6,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (5.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (2.32.3)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (4.12.2)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (0.23.0)
# Requirement already satisfied: pyarrow<17.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix<1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object_detection==0.1) (0.6)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lvis->object_detection==0.1) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from lvis->object_detection==0.1) (1.4.7)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from lvis->object_detection==0.1) (4.10.0.84)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object_detection==0.1) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object_detection==0.1) (4.55.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow_io->object_detection==0.1) (0.23.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object_detection==0.1) (2.27.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object_detection==0.1) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object_detection==0.1) (2.19.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object_detection==0.1) (4.1.1)
# Requirement already satisfied: docopt in /usr/local/lib/python3.10/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object_detection==0.1) (0.6.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object_detection==0.1) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object_detection==0.1) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object_detection==0.1) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object_detection==0.1) (0.22.3)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object_detection==0.1) (2024.12.14)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object_detection==0.1) (4.67.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object_detection==0.1) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object_detection==0.1) (2.2.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object_detection==0.1) (6.2.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo<5.0.0,>=3.8.0->apache-beam->object_detection==0.1) (2.7.0)
# Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from redis<6,>=5.0.0->apache-beam->object_detection==0.1) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object_detection==0.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object_detection==0.1) (3.10)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (24.3.25)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (3.12.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (3.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (75.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (1.17.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (2.8.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (2.8.0)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-hub>=0.6.0->tf-models-official==2.8.0->object_detection==0.1) (2.15.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official==2.8.0->object_detection==0.1) (0.1.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official==2.8.0->object_detection==0.1) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official==2.8.0->object_detection==0.1) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official==2.8.0->object_detection==0.1) (4.9)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->tf-models-official==2.8.0->object_detection==0.1) (1.6.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons->tf-models-official==2.8.0->object_detection==0.1) (2.13.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0->object_detection==0.1) (8.1.7)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0->object_detection==0.1) (4.2.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0->object_detection==0.1) (2.3)
# Requirement already satisfied: simple-parsing in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0->object_detection==0.1) (0.1.6)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0->object_detection==0.1) (1.13.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0->object_detection==0.1) (0.10.2)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0->object_detection==0.1) (0.5.1)
# Requirement already satisfied: etils>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->tf-models-official==2.8.0->object_detection==0.1) (1.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (0.45.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->tf-models-official==2.8.0->object_detection==0.1) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->tf-models-official==2.8.0->object_detection==0.1) (6.4.5)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->tf-models-official==2.8.0->object_detection==0.1) (3.21.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official==2.8.0->object_detection==0.1) (1.66.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0->object_detection==0.1) (5.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official==2.8.0->object_detection==0.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official==2.8.0->object_detection==0.1) (3.5.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (3.1.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle>=1.3.9->tf-models-official==2.8.0->object_detection==0.1) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official==2.8.0->object_detection==0.1) (1.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.10/dist-packages (from simple-parsing->tensorflow-datasets->tf-models-official==2.8.0->object_detection==0.1) (0.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (3.0.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object_detection==0.1) (3.2.2)
# Building wheels for collected packages: object_detection
#   Building wheel for object_detection (setup.py) ... done
#   Created wheel for object_detection: filename=object_detection-0.1-py3-none-any.whl size=1697355 sha256=0b66b4beb996b8ed79b452095473cc7277a463ca757d4b46af7e70577e811fdd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vbwze8fq/wheels/53/dd/70/2de274d6c443c69d367bd6a5606f95e5a6df61aacf1435ec0d
# Successfully built object_detection
# Installing collected packages: object_detection
#   Attempting uninstall: object_detection
#     Found existing installation: object_detection 0.1
#     Uninstalling object_detection-0.1:
#       Successfully uninstalled object_detection-0.1
# Successfully installed object_detection-0.1
# Collecting tensorflow==2.8.0
#   Using cached tensorflow-2.8.0-cp310-cp310-manylinux2010_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (24.3.25)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (3.12.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (3.4.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (4.25.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.17.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (2.8.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow==2.8.0)
#   Using cached tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (0.23.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.65.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.8.0) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.2.2)
# Downloading tensorflow-2.8.0-cp310-cp310-manylinux2010_x86_64.whl (497.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 3.2 MB/s eta 0:00:00
# Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 757.0 kB/s eta 0:00:00
# Installing collected packages: tf-estimator-nightly, tensorflow
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.1
#     Uninstalling tensorflow-2.8.1:
#       Successfully uninstalled tensorflow-2.8.1
# Successfully installed tensorflow-2.8.0 tf-estimator-nightly-2.8.0.dev2021122109
# Requirement already satisfied: tensorflow_io==0.23.1 in /usr/local/lib/python3.10/dist-packages (0.23.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow_io==0.23.1) (0.23.1)
# --2024-12-21 01:10:39--  https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.20.126
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.20.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 190 [application/octet-stream]
# Saving to: ‘cuda-ubuntu1804.pin’
#
# cuda-ubuntu1804.pin 100%[===================>]     190  --.-KB/s    in 0s
#
# 2024-12-21 01:10:39 (5.27 MB/s) - ‘cuda-ubuntu1804.pin’ saved [190/190]
#
# --2024-12-21 01:10:39--  http://developer.download.nvidia.com/compute/cuda/11.0.2/local_installers/cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.20.126
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.20.126|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://developer.download.nvidia.com/compute/cuda/11.0.2/local_installers/cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb [following]
# --2024-12-21 01:10:39--  https://developer.download.nvidia.com/compute/cuda/11.0.2/local_installers/cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.20.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2273753684 (2.1G) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb’
#
# cuda-repo-ubuntu180 100%[===================>]   2.12G   120MB/s    in 12s
#
# 2024-12-21 01:10:51 (180 MB/s) - ‘cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb’ saved [2273753684/2273753684]
#
# Selecting previously unselected package cuda-repo-ubuntu1804-11-0-local.
# (Reading database ... 123634 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb ...
# Unpacking cuda-repo-ubuntu1804-11-0-local (11.0.2-450.51.05-1) ...
# Setting up cuda-repo-ubuntu1804-11-0-local (11.0.2-450.51.05-1) ...
#
# The public CUDA GPG key does not appear to be installed.
# To install the key, run this command:
# sudo apt-key add /var/cuda-repo-ubuntu1804-11-0-local/7fa2af80.pub
#
# Warning: apt-key is deprecated. Manage keyring files in trusted.gpg.d instead (see apt-key(8)).
# OK
# Get:1 file:/var/cuda-repo-ubuntu1804-11-0-local  InRelease
# Ign:1 file:/var/cuda-repo-ubuntu1804-11-0-local  InRelease
# Get:2 file:/var/cuda-repo-ubuntu1804-11-0-local  Release [564 B]
# Get:2 file:/var/cuda-repo-ubuntu1804-11-0-local  Release [564 B]
# Get:3 file:/var/cuda-repo-ubuntu1804-11-0-local  Release.gpg [836 B]
# Get:3 file:/var/cuda-repo-ubuntu1804-11-0-local  Release.gpg [836 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 file:/var/cuda-repo-ubuntu1804-11-0-local  Packages [23.9 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,448 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,517 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,226 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,517 kB]
# Get:19 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,564 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,614 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,830 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [81.4 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [33.8 kB]
# Get:24 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,632 kB]
# Fetched 26.9 MB in 3s (9,027 kB/s)
# Reading package lists... Done
# W: file:/var/cuda-repo-ubuntu1804-11-0-local/Release.gpg: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cuda-command-line-tools-11-0 cuda-compiler-11-0 cuda-cudart-11-0
#   cuda-cudart-dev-11-0 cuda-cuobjdump-11-0 cuda-cupti-11-0 cuda-cupti-dev-11-0
#   cuda-documentation-11-0 cuda-driver-dev-11-0 cuda-gdb-11-0
#   cuda-libraries-11-0 cuda-libraries-dev-11-0 cuda-memcheck-11-0
#   cuda-nsight-11-0 cuda-nsight-compute-11-0 cuda-nsight-systems-11-0
#   cuda-nvcc-11-0 cuda-nvdisasm-11-0 cuda-nvml-dev-11-0 cuda-nvprof-11-0
#   cuda-nvprune-11-0 cuda-nvrtc-11-0 cuda-nvrtc-dev-11-0 cuda-nvtx-11-0
#   cuda-nvvp-11-0 cuda-samples-11-0 cuda-sanitizer-11-0 cuda-tools-11-0
#   cuda-visual-tools-11-0 default-jre default-jre-headless fonts-dejavu-core
#   fonts-dejavu-extra freeglut3 freeglut3-dev libatk-wrapper-java
#   libatk-wrapper-java-jni libcublas-11-0 libcublas-dev-11-0 libcufft-11-0
#   libcufft-dev-11-0 libcurand-11-0 libcurand-dev-11-0 libcusolver-11-0
#   libcusolver-dev-11-0 libcusparse-11-0 libcusparse-dev-11-0 libegl-dev
#   libfontenc1 libgl-dev libgl1-mesa-dev libgles-dev libgles1 libglu1-mesa
#   libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev libice-dev
#   libnpp-11-0 libnpp-dev-11-0 libnvjpeg-11-0 libnvjpeg-dev-11-0 libopengl-dev
#   libsm-dev libxcb-cursor0 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxfixes-dev libxi-dev libxkbcommon-x11-0 libxkbfile1 libxmu-dev
#   libxmu-headers libxt-dev libxtst6 libxxf86dga1 nsight-systems-2024.5.1
#   openjdk-11-jre x11-utils
# Suggested packages:
#   libice-doc libsm-doc libxt-doc mesa-utils
# The following NEW packages will be installed:
#   cuda-command-line-tools-11-0 cuda-compiler-11-0 cuda-cudart-11-0
#   cuda-cudart-dev-11-0 cuda-cuobjdump-11-0 cuda-cupti-11-0 cuda-cupti-dev-11-0
#   cuda-documentation-11-0 cuda-driver-dev-11-0 cuda-gdb-11-0
#   cuda-libraries-11-0 cuda-libraries-dev-11-0 cuda-memcheck-11-0
#   cuda-nsight-11-0 cuda-nsight-compute-11-0 cuda-nsight-systems-11-0
#   cuda-nvcc-11-0 cuda-nvdisasm-11-0 cuda-nvml-dev-11-0 cuda-nvprof-11-0
#   cuda-nvprune-11-0 cuda-nvrtc-11-0 cuda-nvrtc-dev-11-0 cuda-nvtx-11-0
#   cuda-nvvp-11-0 cuda-samples-11-0 cuda-sanitizer-11-0 cuda-toolkit-11-0
#   cuda-tools-11-0 cuda-visual-tools-11-0 default-jre default-jre-headless
#   fonts-dejavu-core fonts-dejavu-extra freeglut3 freeglut3-dev
#   libatk-wrapper-java libatk-wrapper-java-jni libcublas-11-0
#   libcublas-dev-11-0 libcufft-11-0 libcufft-dev-11-0 libcurand-11-0
#   libcurand-dev-11-0 libcusolver-11-0 libcusolver-dev-11-0 libcusparse-11-0
#   libcusparse-dev-11-0 libegl-dev libfontenc1 libgl-dev libgl1-mesa-dev
#   libgles-dev libgles1 libglu1-mesa libglu1-mesa-dev libglvnd-core-dev
#   libglvnd-dev libglx-dev libice-dev libnpp-11-0 libnpp-dev-11-0
#   libnvjpeg-11-0 libnvjpeg-dev-11-0 libopengl-dev libsm-dev libxcb-cursor0
#   libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0 libxcb-util1
#   libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxfixes-dev libxi-dev
#   libxkbcommon-x11-0 libxkbfile1 libxmu-dev libxmu-headers libxt-dev libxtst6
#   libxxf86dga1 nsight-systems-2024.5.1 openjdk-11-jre x11-utils
# 0 upgraded, 87 newly installed, 0 to remove and 50 not upgraded.
# Need to get 361 MB/1,943 MB of archives.
# After this operation, 4,022 MB of additional disk space will be used.
# Get:1 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-cudart-11-0 11.0.194-1 [129 kB]
# Get:2 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-driver-dev-11-0 11.0.194-1 [25.0 kB]
# Get:3 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-cudart-dev-11-0 11.0.194-1 [1,662 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-systems-2024.5.1 2024.5.1.113-245134619542v0 [356 MB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3 amd64 2.8.1-6 [74.0 kB]
# Get:6 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-nvcc-11-0 11.0.194-1 [21.1 MB]
# Get:7 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-cupti-11-0 11.0.194-1 [10.5 MB]
# Get:8 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-cupti-dev-11-0 11.0.194-1 [2,276 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [6,848 B]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa-dev amd64 9.0.2-1 [231 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libice-dev amd64 2:1.0.10-1build2 [51.4 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsm-dev amd64 2:1.2.3-1build2 [18.1 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxt-dev amd64 1:1.2.1-1 [396 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3-dev amd64 2.8.1-6 [126 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmu-headers all 2:1.1.3-3 [54.1 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmu-dev amd64 2:1.1.3-3 [54.6 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfixes-dev amd64 1:6.0.0-1 [12.2 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxi-dev amd64 2:1.8-1build1 [193 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.25+9-1ubuntu1~22.04 [216 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:32 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-nvdisasm-11-0 11.0.194-1 [27.3 MB]
# Get:33 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-cuobjdump-11-0 11.0.194-1 [103 kB]
# Get:34 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-gdb-11-0 11.0.194-1 [3,891 kB]
# Get:35 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-memcheck-11-0 11.0.194-1 [144 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:43 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-nvprof-11-0 11.0.194-1 [1,911 kB]
# Get:44 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-nvtx-11-0 11.0.167-1 [51.1 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxcb-cursor0 amd64 0.1.1-4ubuntu1 [10.5 kB]
# Get:48 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-sanitizer-11-0 11.0.194-1 [7,220 kB]
# Get:49 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-command-line-tools-11-0 11.0.2-1 [2,474 B]
# Get:50 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-nvprune-11-0 11.0.167-1 [53.1 kB]
# Get:51 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-compiler-11-0 11.0.2-1 [2,416 B]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:54 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-nvrtc-11-0 11.0.194-1 [6,521 kB]
# Get:55 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-nvrtc-dev-11-0 11.0.194-1 [22.1 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:62 file:/var/cuda-repo-ubuntu1804-11-0-local  libcusolver-11-0 10.5.0.218-1 [277 MB]
# Get:63 file:/var/cuda-repo-ubuntu1804-11-0-local  libcusolver-dev-11-0 10.5.0.218-1 [17.6 MB]
# Get:64 file:/var/cuda-repo-ubuntu1804-11-0-local  libcublas-11-0 11.1.0.229-1 [118 MB]
# Get:65 file:/var/cuda-repo-ubuntu1804-11-0-local  libcublas-dev-11-0 11.1.0.229-1 [120 MB]
# Get:66 file:/var/cuda-repo-ubuntu1804-11-0-local  libcufft-11-0 10.2.0.218-1 [94.1 MB]
# Get:67 file:/var/cuda-repo-ubuntu1804-11-0-local  libcufft-dev-11-0 10.2.0.218-1 [172 MB]
# Get:68 file:/var/cuda-repo-ubuntu1804-11-0-local  libcurand-11-0 10.2.1.218-1 [39.2 MB]
# Get:69 file:/var/cuda-repo-ubuntu1804-11-0-local  libcurand-dev-11-0 10.2.1.218-1 [39.2 MB]
# Get:70 file:/var/cuda-repo-ubuntu1804-11-0-local  libcusparse-11-0 11.1.0.218-1 [71.2 MB]
# Get:71 file:/var/cuda-repo-ubuntu1804-11-0-local  libcusparse-dev-11-0 11.1.0.218-1 [71.4 MB]
# Get:72 file:/var/cuda-repo-ubuntu1804-11-0-local  libnpp-11-0 11.1.0.218-1 [56.6 MB]
# Get:73 file:/var/cuda-repo-ubuntu1804-11-0-local  libnpp-dev-11-0 11.1.0.218-1 [57.4 MB]
# Get:74 file:/var/cuda-repo-ubuntu1804-11-0-local  libnvjpeg-11-0 11.1.0.218-1 [1,391 kB]
# Get:75 file:/var/cuda-repo-ubuntu1804-11-0-local  libnvjpeg-dev-11-0 11.1.0.218-1 [1,321 kB]
# Get:76 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-samples-11-0 11.0.194-1 [68.1 MB]
# Get:77 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-documentation-11-0 11.0.207-1 [59.6 MB]
# Get:78 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-libraries-11-0 11.0.2-1 [2,490 B]
# Get:79 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-libraries-dev-11-0 11.0.2-1 [2,514 B]
# Get:80 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-nsight-11-0 11.0.194-1 [119 MB]
# Get:81 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-nsight-compute-11-0 11.0.2-1 [3,718 B]
# Get:82 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-nsight-systems-11-0 11.0.2-1 [3,280 B]
# Get:83 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-nvml-dev-11-0 11.0.167-1 [71.9 kB]
# Get:84 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-nvvp-11-0 11.0.194-1 [115 MB]
# Get:85 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-visual-tools-11-0 11.0.2-1 [2,942 B]
# Get:86 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-tools-11-0 11.0.2-1 [2,380 B]
# Get:87 file:/var/cuda-repo-ubuntu1804-11-0-local  cuda-toolkit-11-0 11.0.2-1 [2,728 B]
# Fetched 361 MB in 16s (22.1 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 87.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package cuda-cudart-11-0.
# (Reading database ... 123721 files and directories currently installed.)
# Preparing to unpack .../00-cuda-cudart-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-cudart-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-driver-dev-11-0.
# Preparing to unpack .../01-cuda-driver-dev-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-driver-dev-11-0 (11.0.194-1) ...
# ...
# Preparing to unpack .../29-libsm-dev_2%3a1.2.3-1build2_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1build2) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../30-libxt-dev_1%3a1.2.1-1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.2.1-1) ...
# Selecting previously unselected package freeglut3-dev:amd64.
# Preparing to unpack .../31-freeglut3-dev_2.8.1-6_amd64.deb ...
# Unpacking freeglut3-dev:amd64 (2.8.1-6) ...
# Selecting previously unselected package libxmu-headers.
# Preparing to unpack .../32-libxmu-headers_2%3a1.1.3-3_all.deb ...
# Unpacking libxmu-headers (2:1.1.3-3) ...
# Selecting previously unselected package libxmu-dev:amd64.
# Preparing to unpack .../33-libxmu-dev_2%3a1.1.3-3_amd64.deb ...
# Unpacking libxmu-dev:amd64 (2:1.1.3-3) ...
# Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../34-libxfixes-dev_1%3a6.0.0-1_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:6.0.0-1) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../35-libxi-dev_2%3a1.8-1build1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.8-1build1) ...
# Selecting previously unselected package cuda-nvrtc-11-0.
# Preparing to unpack .../36-cuda-nvrtc-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-nvrtc-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-11-0.
# Preparing to unpack .../37-cuda-nvrtc-dev-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-11-0 (11.0.194-1) ...
# Selecting previously unselected package libcusolver-11-0.
# Preparing to unpack .../38-libcusolver-11-0_10.5.0.218-1_amd64.deb ...
# Unpacking libcusolver-11-0 (10.5.0.218-1) ...
# Selecting previously unselected package libcusolver-dev-11-0.
# Preparing to unpack .../39-libcusolver-dev-11-0_10.5.0.218-1_amd64.deb ...
# Unpacking libcusolver-dev-11-0 (10.5.0.218-1) ...
# Selecting previously unselected package libcublas-11-0.
# Preparing to unpack .../40-libcublas-11-0_11.1.0.229-1_amd64.deb ...
# Unpacking libcublas-11-0 (11.1.0.229-1) ...
# Selecting previously unselected package libcublas-dev-11-0.
# Preparing to unpack .../41-libcublas-dev-11-0_11.1.0.229-1_amd64.deb ...
# Unpacking libcublas-dev-11-0 (11.1.0.229-1) ...
# Selecting previously unselected package libcufft-11-0.
# Preparing to unpack .../42-libcufft-11-0_10.2.0.218-1_amd64.deb ...
# Unpacking libcufft-11-0 (10.2.0.218-1) ...
# Selecting previously unselected package libcufft-dev-11-0.
# Preparing to unpack .../43-libcufft-dev-11-0_10.2.0.218-1_amd64.deb ...
# Unpacking libcufft-dev-11-0 (10.2.0.218-1) ...
# Selecting previously unselected package libcurand-11-0.
# Preparing to unpack .../44-libcurand-11-0_10.2.1.218-1_amd64.deb ...
# Unpacking libcurand-11-0 (10.2.1.218-1) ...
# Selecting previously unselected package libcurand-dev-11-0.
# Preparing to unpack .../45-libcurand-dev-11-0_10.2.1.218-1_amd64.deb ...
# Unpacking libcurand-dev-11-0 (10.2.1.218-1) ...
# Selecting previously unselected package libcusparse-11-0.
# Preparing to unpack .../46-libcusparse-11-0_11.1.0.218-1_amd64.deb ...
# Unpacking libcusparse-11-0 (11.1.0.218-1) ...
# Selecting previously unselected package libcusparse-dev-11-0.
# Preparing to unpack .../47-libcusparse-dev-11-0_11.1.0.218-1_amd64.deb ...
# Unpacking libcusparse-dev-11-0 (11.1.0.218-1) ...
# Selecting previously unselected package libnpp-11-0.
# Preparing to unpack .../48-libnpp-11-0_11.1.0.218-1_amd64.deb ...
# Unpacking libnpp-11-0 (11.1.0.218-1) ...
# Selecting previously unselected package libnpp-dev-11-0.
# Preparing to unpack .../49-libnpp-dev-11-0_11.1.0.218-1_amd64.deb ...
# Unpacking libnpp-dev-11-0 (11.1.0.218-1) ...
# Selecting previously unselected package libnvjpeg-11-0.
# Preparing to unpack .../50-libnvjpeg-11-0_11.1.0.218-1_amd64.deb ...
# Unpacking libnvjpeg-11-0 (11.1.0.218-1) ...
# Selecting previously unselected package libnvjpeg-dev-11-0.
# Preparing to unpack .../51-libnvjpeg-dev-11-0_11.1.0.218-1_amd64.deb ...
# Unpacking libnvjpeg-dev-11-0 (11.1.0.218-1) ...
# Selecting previously unselected package cuda-samples-11-0.
# Preparing to unpack .../52-cuda-samples-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-samples-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-documentation-11-0.
# Preparing to unpack .../53-cuda-documentation-11-0_11.0.207-1_amd64.deb ...
# Unpacking cuda-documentation-11-0 (11.0.207-1) ...
# Selecting previously unselected package cuda-libraries-11-0.
# Preparing to unpack .../54-cuda-libraries-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-libraries-11-0 (11.0.2-1) ...
# Selecting previously unselected package cuda-libraries-dev-11-0.
# Preparing to unpack .../55-cuda-libraries-dev-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-libraries-dev-11-0 (11.0.2-1) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../56-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../57-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../58-openjdk-11-jre_11.0.25+9-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../59-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package cuda-nsight-11-0.
# Preparing to unpack .../60-cuda-nsight-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-nsight-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-nsight-compute-11-0.
# Preparing to unpack .../61-cuda-nsight-compute-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-nsight-compute-11-0 (11.0.2-1) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../62-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../63-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../64-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../65-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../66-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../67-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../68-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../69-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../70-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-cursor0:amd64.
# Preparing to unpack .../71-libxcb-cursor0_0.1.1-4ubuntu1_amd64.deb ...
# Unpacking libxcb-cursor0:amd64 (0.1.1-4ubuntu1) ...
# Selecting previously unselected package nsight-systems-2024.5.1.
# Preparing to unpack .../72-nsight-systems-2024.5.1_2024.5.1.113-245134619542v0_amd64.deb ...
# Unpacking nsight-systems-2024.5.1 (2024.5.1.113-245134619542v0) ...
# Selecting previously unselected package cuda-nsight-systems-11-0.
# Preparing to unpack .../73-cuda-nsight-systems-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-nsight-systems-11-0 (11.0.2-1) ...
# Selecting previously unselected package cuda-nvml-dev-11-0.
# Preparing to unpack .../74-cuda-nvml-dev-11-0_11.0.167-1_amd64.deb ...
# Unpacking cuda-nvml-dev-11-0 (11.0.167-1) ...
# Selecting previously unselected package cuda-nvvp-11-0.
# Preparing to unpack .../75-cuda-nvvp-11-0_11.0.194-1_amd64.deb ...
# Unpacking cuda-nvvp-11-0 (11.0.194-1) ...
# Selecting previously unselected package cuda-visual-tools-11-0.
# Preparing to unpack .../76-cuda-visual-tools-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-visual-tools-11-0 (11.0.2-1) ...
# Selecting previously unselected package cuda-tools-11-0.
# Preparing to unpack .../77-cuda-tools-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-tools-11-0 (11.0.2-1) ...
# Selecting previously unselected package cuda-toolkit-11-0.
# Preparing to unpack .../78-cuda-toolkit-11-0_11.0.2-1_amd64.deb ...
# Unpacking cuda-toolkit-11-0 (11.0.2-1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../79-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../80-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../81-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../82-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../83-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../84-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../85-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../86-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up libcurand-11-0 (10.2.1.218-1) ...
# Setting up libcublas-11-0 (11.1.0.229-1) ...
# Setting up libxmu-headers (2:1.1.3-3) ...
# Setting up cuda-nvtx-11-0 (11.0.167-1) ...
# Setting up freeglut3:amd64 (2.8.1-6) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up libcusolver-11-0 (10.5.0.218-1) ...
# Setting up libice-dev:amd64 (2:1.0.10-1build2) ...
# Setting up cuda-driver-dev-11-0 (11.0.194-1) ...
# Setting up libsm-dev:amd64 (2:1.2.3-1build2) ...
# Setting up cuda-nsight-compute-11-0 (11.0.2-1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up cuda-memcheck-11-0 (11.0.194-1) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up openjdk-11-jre:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up cuda-nvprune-11-0 (11.0.167-1) ...
# Setting up libnvjpeg-11-0 (11.1.0.218-1) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up cuda-cudart-11-0 (11.0.194-1) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up libxfixes-dev:amd64 (1:6.0.0-1) ...
# Setting up cuda-nvprof-11-0 (11.0.194-1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1) ...
# Setting up cuda-nvml-dev-11-0 (11.0.167-1) ...
# Setting up libxcb-cursor0:amd64 (0.1.1-4ubuntu1) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up libcusparse-11-0 (11.1.0.218-1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up cuda-cuobjdump-11-0 (11.0.194-1) ...
# Setting up libcufft-11-0 (10.2.0.218-1) ...
# Setting up cuda-cudart-dev-11-0 (11.0.194-1) ...
# Setting up cuda-nvrtc-11-0 (11.0.194-1) ...
# Setting up cuda-sanitizer-11-0 (11.0.194-1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libcufft-dev-11-0 (10.2.0.218-1) ...
# Setting up libnpp-11-0 (11.1.0.218-1) ...
# Setting up libcusolver-dev-11-0 (10.5.0.218-1) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up cuda-nvdisasm-11-0 (11.0.194-1) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up libxi-dev:amd64 (2:1.8-1build1) ...
# Setting up libcublas-dev-11-0 (11.1.0.229-1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up libcusparse-dev-11-0 (11.1.0.218-1) ...
# Setting up cuda-nvvp-11-0 (11.0.194-1) ...
# Setting up libcurand-dev-11-0 (10.2.1.218-1) ...
# Setting up libnpp-dev-11-0 (11.1.0.218-1) ...
# Setting up cuda-libraries-11-0 (11.0.2-1) ...
# Setting up cuda-gdb-11-0 (11.0.194-1) ...
# Setting up cuda-nvrtc-dev-11-0 (11.0.194-1) ...
# Setting up nsight-systems-2024.5.1 (2024.5.1.113-245134619542v0) ...
# update-alternatives: using /opt/nvidia/nsight-systems/2024.5.1/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2024.5.1/host-linux-x64/nsys-ui to provide /usr/local/bin/nsys-ui (nsys-ui) in auto mode
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up cuda-nsight-11-0 (11.0.194-1) ...
# Setting up libnvjpeg-dev-11-0 (11.1.0.218-1) ...
# Setting up libxmu-dev:amd64 (2:1.1.3-3) ...
# Setting up cuda-nvcc-11-0 (11.0.194-1) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Setting up cuda-libraries-dev-11-0 (11.0.2-1) ...
# Setting up cuda-cupti-11-0 (11.0.194-1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up cuda-nsight-systems-11-0 (11.0.2-1) ...
# Setting up cuda-visual-tools-11-0 (11.0.2-1) ...
# Setting up cuda-compiler-11-0 (11.0.2-1) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up cuda-cupti-dev-11-0 (11.0.194-1) ...
# Setting up libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up cuda-command-line-tools-11-0 (11.0.2-1) ...
# Setting up freeglut3-dev:amd64 (2.8.1-6) ...
# Setting up cuda-tools-11-0 (11.0.2-1) ...
# Setting up cuda-samples-11-0 (11.0.194-1) ...
# Setting up cuda-documentation-11-0 (11.0.207-1) ...
# Setting up cuda-toolkit-11-0 (11.0.2-1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %% [markdown]
# You may get warnings or errors related to package dependencies in the previous code block, but you can ignore them for now.
#
# Let's test our installation by running `model_builder_tf2_test.py` to make sure everything is working as expected. Run the following code block and confirm that it finishes without errors. If you get errors, try Googling them or checking the FAQ at the end of this Colab.

# %%
# Run Model Bulider Test file, just to verify everything's working properly
# !python /content/models/research/object_detection/builders/model_builder_tf2_test.py

# %% [markdown]
# # 3.&nbsp;Upload Image Dataset and Prepare Training Data

# %% [markdown]
# In this section, we'll upload our data and prepare it for training with TensorFlow. We'll upload our images, split them into train, validation, and test folders, and then run scripts for creating TFRecords from our data.
#
# First, on your local PC, zip all your training images and XML files into a single folder called "images.zip". The files should be directly inside the zip folder, or in a nested folder as shown below:
# ```
# images.zip
# -- images
#   -- img1.jpg
#   -- img1.xml
#   -- img2.jpg
#   -- img2.xml
#   ...
# ```

# %% [markdown]
# ### 3.1 Upload images
# There are three options for moving the image files to this Colab instance.

# %% [markdown]
# **Option 1. Upload through Google Colab**
#
# Upload the "images.zip" file to the Google Colab instance by clicking the "Files" icon on the left hand side of the browser, and then the "Upload to session storage" icon. Select the zip folder to upload it.
#
# ![](https://raw.githubusercontent.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/master/doc/colab_upload_button.png)

# %% [markdown]
# **Option 2. Copy from Google Drive**
#
# You can also upload your images to your personal Google Drive, mount the drive on this Colab session, and copy them over to the Colab filesystem. This option works well if you want to upload the images beforehand so you don't have to wait for them to upload each time you restart this Colab. If you have more than 50MB worth of images, I recommend using this option.
#
# First, upload the "images.zip" file to your Google Drive, and make note of the folder you uploaded them to. Replace `MyDrive/path/to/images.zip` with the path to your zip file. (For example, I uploaded the zip file to folder called "change-counter1", so I would use `MyDrive/change-counter1/images.zip` for the path). Then, run the following block of code to mount your Google Drive to this Colab session and copy the folder to this filesystem.

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !cp /content/gdrive/MyDrive/path/to/images.zip /content

# %% [markdown]
# **Option 3. Use coin detection dataset**
#
# If you don't have a dataset and just want to try training a model, you can download my coin image dataset to use as an example. I've uploaded a dataset containing 750 labeled images of pennies, nickels, dimes, and quarters. Run the following code block to download the dataset.

# %%
# !wget -O /content/images.zip https://www.dropbox.com/s/gk57ec3v8dfuwcp/CoinPics_11NOV22.zip?dl=0  # United States coin images

# %% [markdown]
# ## 3.2 Split images into train, validation, and test folders
# At this point, whether you used Option 1, 2, or 3, you should be able to click the folder icon on the left and see your "images.zip" file in the list of files. Now that the dataset is uploaded, let's unzip it and create some folders to hold the images. These directories are created in the /content folder in this instance's filesystem. You can browse the filesystem by clicking the "Files" icon on the left.

# %%
# !mkdir /content/images
# !unzip -q images.zip -d /content/images/all
# !mkdir /content/images/train; mkdir /content/images/validation; mkdir /content/images/test

# %% [markdown]
# Next, we'll split the images into train, validation, and test sets. Here's what each set is used for:
#
#
#
# *   **Train**: These are the actual images used to train the model. In each step of training, a batch of images from the "train" set is passed into the neural network. The network predicts classes and locations of objects in the images. The training algorithm calculates the loss (i.e. how "wrong" the predictions were) and adjusts the network weights through backpropagation.
#
#
# *   **Validation**: Images from the "validation" set can be used by the training algorithm to check the progress of training and adjust hyperparameters (like learning rate). Unlike "train" images, these images are only used periodically during training (i.e. once every certain number of training steps).
#
#
# * **Test**: These images are never seen by the neural network during training. They are intended to be used by a human to perform final testing of the model to check how accurate the model is.
#
# I wrote a Python script to randomly move 80% of the images to the "train" folder, 10% to the "validation" folder, and 10% to the "test" folder. Click play on the following block to download the script and execute it.

# %%
# !wget https://raw.githubusercontent.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/master/util_scripts/train_val_test_split.py
# !python train_val_test_split.py

# %% [markdown]
# ## 3.3 Create Labelmap and TFRecords
# Finally, we need to create a labelmap for the detector and convert the images into a data file format called TFRecords, which are used by TensorFlow for training. We'll use Python scripts to automatically convert the data into TFRecord format. Before running them, we need to define a labelmap for our classes.
#
# The code section below will create a "labelmap.txt" file that contains a list of classes. Replace the `class1`, `class2`, `class3` text with your own classes (for example, `penny`, `nickel`, `dime`, `quarter`), adding a new line for each class. Then, click play to execute the code.

# %%
# prompt: unzip /content/banknote.v1i.tfrecord.zip

# !unzip /content/banknote.v1i.tfrecord.zip
# Out:
# Archive:  /content/banknote.v1i.tfrecord.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#    creating: test/
#  extracting: test/banknote.tfrecord
#   inflating: test/banknote_label_map.pbtxt
#    creating: train/
#  extracting: train/banknote.tfrecord
#   inflating: train/banknote_label_map.pbtxt
#    creating: valid/
#  extracting: valid/banknote.tfrecord
#   inflating: valid/banknote_label_map.pbtxt

# %%
# prompt: unzip /content/banknote.v1i.voc.zip

# !unzip /content/banknote.v1i.voc.zip
# Out:
# Archive:  /content/banknote.v1i.voc.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#    creating: test/
#  extracting: test/100_002_png.rf.be3d75e2cdd91471bf930ada41816e61.jpg
#   inflating: test/100_002_png.rf.be3d75e2cdd91471bf930ada41816e61.xml
#  extracting: test/100_003_png.rf.ed47751b470a511bda888c23572d3ff2.jpg
#   inflating: test/100_003_png.rf.ed47751b470a511bda888c23572d3ff2.xml
#  extracting: test/100_012_png.rf.0db2ee45fc3967fe40b8ea2cab41530b.jpg
#   inflating: test/100_012_png.rf.0db2ee45fc3967fe40b8ea2cab41530b.xml
#  extracting: test/100_017_png.rf.2d113858977544dd07eba06a4ef1f168.jpg
#   inflating: test/100_017_png.rf.2d113858977544dd07eba06a4ef1f168.xml
#  extracting: test/100_028_png.rf.77183c617e1d95346d454e212f9fa460.jpg
#   inflating: test/100_028_png.rf.77183c617e1d95346d454e212f9fa460.xml
#  extracting: test/10_003_png.rf.9939bb2e6ba74c3eb845d5f5476b272d.jpg
#   inflating: test/10_003_png.rf.9939bb2e6ba74c3eb845d5f5476b272d.xml
#  extracting: test/10_016_png.rf.eb83cde7b1c9493356648d77de9ae56c.jpg
#   inflating: test/10_016_png.rf.eb83cde7b1c9493356648d77de9ae56c.xml
#  extracting: test/10_022_png.rf.b90b57dae72c75fe76dccd7a46194941.jpg
#   inflating: test/10_022_png.rf.b90b57dae72c75fe76dccd7a46194941.xml
#  extracting: test/10_026_png.rf.f1e8d779eb7520ccd8c3f770a543ac5d.jpg
#   inflating: test/10_026_png.rf.f1e8d779eb7520ccd8c3f770a543ac5d.xml
#  extracting: test/200_022_png.rf.b7942f6d0eac99120d9c1e71ee02f3d6.jpg
#   inflating: test/200_022_png.rf.b7942f6d0eac99120d9c1e71ee02f3d6.xml
#  extracting: test/200_027_png.rf.3e97ee0c1c70146e4f53d045711d7438.jpg
#   inflating: test/200_027_png.rf.3e97ee0c1c70146e4f53d045711d7438.xml
#  extracting: test/20_001_png.rf.58c5f20c82ed6342824d32afdf1c1e43.jpg
#   inflating: test/20_001_png.rf.58c5f20c82ed6342824d32afdf1c1e43.xml
#  extracting: test/50_008_png.rf.e512e58332a9e81cabbed9e18896fa93.jpg
#   inflating: test/50_008_png.rf.e512e58332a9e81cabbed9e18896fa93.xml
#  extracting: test/50_011_png.rf.c8288d3d321f32355322e11fa7c7bc58.jpg
#   inflating: test/50_011_png.rf.c8288d3d321f32355322e11fa7c7bc58.xml
#  extracting: test/50_026_png.rf.49ac5d5a54ca78e04765e0a9f4d9838c.jpg
#   inflating: test/50_026_png.rf.49ac5d5a54ca78e04765e0a9f4d9838c.xml
#  extracting: test/5_001_png.rf.7ca1dfa13e60f4ff3258644ebe6460c9.jpg
#   inflating: test/5_001_png.rf.7ca1dfa13e60f4ff3258644ebe6460c9.xml
#  extracting: test/5_015_png.rf.4ca0dd3700479b5ff41e1d3bb7b40036.jpg
#   inflating: test/5_015_png.rf.4ca0dd3700479b5ff41e1d3bb7b40036.xml
#  extracting: test/5_026_png.rf.f86931e14588159434977ba0da52d0bc.jpg
#   inflating: test/5_026_png.rf.f86931e14588159434977ba0da52d0bc.xml
#    creating: train/
#  extracting: train/100_004_png.rf.012361ca93bdffb749fe843be00ed5fb.jpg
#   inflating: train/100_004_png.rf.012361ca93bdffb749fe843be00ed5fb.xml
#  extracting: train/100_004_png.rf.c29d40350db9bc29c8c098324a81d57f.jpg
#   inflating: train/100_004_png.rf.c29d40350db9bc29c8c098324a81d57f.xml
#  extracting: train/100_004_png.rf.f5d3b5b3dbeb13420719fbde51c7c253.jpg
#   inflating: train/100_004_png.rf.f5d3b5b3dbeb13420719fbde51c7c253.xml
#  extracting: train/100_005_png.rf.2480de70a01fd9b48682daa91fcee8c3.jpg
#   inflating: train/100_005_png.rf.2480de70a01fd9b48682daa91fcee8c3.xml
#  extracting: train/100_005_png.rf.7570638f7bbbd5212eec5c9e3938aaa9.jpg
#   inflating: train/100_005_png.rf.7570638f7bbbd5212eec5c9e3938aaa9.xml
#  extracting: train/100_005_png.rf.dfd86eb733142d252ea7d631037b56ea.jpg
#   inflating: train/100_005_png.rf.dfd86eb733142d252ea7d631037b56ea.xml
#  extracting: train/100_007_png.rf.1afedb33d2815c4a31a0bdefd47f4813.jpg
#   inflating: train/100_007_png.rf.1afedb33d2815c4a31a0bdefd47f4813.xml
#  extracting: train/100_007_png.rf.6d5acb252da892498982288ff5e36e6b.jpg
#   inflating: train/100_007_png.rf.6d5acb252da892498982288ff5e36e6b.xml
#  extracting: train/100_007_png.rf.be6bfa250f57ad1152a6e95bcb7de1c3.jpg
#   inflating: train/100_007_png.rf.be6bfa250f57ad1152a6e95bcb7de1c3.xml
#  extracting: train/100_008_png.rf.106efaeec73671f0b910d4f146c1396b.jpg
#   inflating: train/100_008_png.rf.106efaeec73671f0b910d4f146c1396b.xml
#  extracting: train/100_008_png.rf.82aef4223236bb789ea85410e7baf6fd.jpg
#   inflating: train/100_008_png.rf.82aef4223236bb789ea85410e7baf6fd.xml
#  extracting: train/100_008_png.rf.f55f5bab54c0140b9e5c51a51a816942.jpg
#   inflating: train/100_008_png.rf.f55f5bab54c0140b9e5c51a51a816942.xml
#  extracting: train/100_009_png.rf.1922776b6a2dc51c4770994f4eb336f5.jpg
#   inflating: train/100_009_png.rf.1922776b6a2dc51c4770994f4eb336f5.xml
#  extracting: train/100_009_png.rf.829c2e36fe9d372963f9062a5708334e.jpg
#   inflating: train/100_009_png.rf.829c2e36fe9d372963f9062a5708334e.xml
#  extracting: train/100_009_png.rf.fbb98eb620ff3a317c0d8c21198c1dd2.jpg
#   inflating: train/100_009_png.rf.fbb98eb620ff3a317c0d8c21198c1dd2.xml
#  extracting: train/100_010_png.rf.67226e418b138bb031a26c6bdf1e7f20.jpg
#   inflating: train/100_010_png.rf.67226e418b138bb031a26c6bdf1e7f20.xml
#  extracting: train/100_010_png.rf.bbb4e77399d58d767ad4de6d61e0e317.jpg
#   inflating: train/100_010_png.rf.bbb4e77399d58d767ad4de6d61e0e317.xml
#  extracting: train/100_010_png.rf.f0b3db4a244149b8b7be89b48f5e99d6.jpg
#   inflating: train/100_010_png.rf.f0b3db4a244149b8b7be89b48f5e99d6.xml
#  extracting: train/100_011_png.rf.264133dbe590935a47446ebc3f29556e.jpg
#   inflating: train/100_011_png.rf.264133dbe590935a47446ebc3f29556e.xml
#  extracting: train/100_011_png.rf.7ca6ded11c5a43633642d4951f9b6fce.jpg
#   inflating: train/100_011_png.rf.7ca6ded11c5a43633642d4951f9b6fce.xml
#  extracting: train/100_011_png.rf.eba0ff09aff2b39d76863878e70fd7b6.jpg
#   inflating: train/100_011_png.rf.eba0ff09aff2b39d76863878e70fd7b6.xml
#  extracting: train/100_013_png.rf.0c33a8d846cff47a29684310f6c23777.jpg
#   inflating: train/100_013_png.rf.0c33a8d846cff47a29684310f6c23777.xml
#  extracting: train/100_013_png.rf.887e0243f0553b2c0b891f085924f6f6.jpg
#   inflating: train/100_013_png.rf.887e0243f0553b2c0b891f085924f6f6.xml
#  extracting: train/100_013_png.rf.c3c309013ec6aee91a456c1d1b107bbe.jpg
#   inflating: train/100_013_png.rf.c3c309013ec6aee91a456c1d1b107bbe.xml
#  extracting: train/100_014_png.rf.00fe35f9af79893d1e845c1a12f82f72.jpg
#   inflating: train/100_014_png.rf.00fe35f9af79893d1e845c1a12f82f72.xml
#  extracting: train/100_014_png.rf.92f40203257297e480f87d91d12da94c.jpg
#   inflating: train/100_014_png.rf.92f40203257297e480f87d91d12da94c.xml
#  extracting: train/100_014_png.rf.e8cb45864669d44d4c4c1682d474eb22.jpg
#   inflating: train/100_014_png.rf.e8cb45864669d44d4c4c1682d474eb22.xml
#  extracting: train/100_015_png.rf.1825588331e6979730683a54b3c434b3.jpg
#   inflating: train/100_015_png.rf.1825588331e6979730683a54b3c434b3.xml
#  extracting: train/100_015_png.rf.4ef5f7d99c142e49436679e6f065647a.jpg
#   inflating: train/100_015_png.rf.4ef5f7d99c142e49436679e6f065647a.xml
#  extracting: train/100_015_png.rf.e0eb30bf274a1b7090867d8242b0e980.jpg
#   inflating: train/100_015_png.rf.e0eb30bf274a1b7090867d8242b0e980.xml
#  extracting: train/100_018_png.rf.0274eb759a738a39681270c1f93d8f2f.jpg
#   inflating: train/100_018_png.rf.0274eb759a738a39681270c1f93d8f2f.xml
#  extracting: train/100_018_png.rf.8c34e31d487d864710c5d70152e7005a.jpg
#   inflating: train/100_018_png.rf.8c34e31d487d864710c5d70152e7005a.xml
#  extracting: train/100_018_png.rf.deaa8cb9bb336417a02f622224074a7d.jpg
#   inflating: train/100_018_png.rf.deaa8cb9bb336417a02f622224074a7d.xml
#  extracting: train/100_020_png.rf.21c445c19e90af2839988037b4a09001.jpg
#   inflating: train/100_020_png.rf.21c445c19e90af2839988037b4a09001.xml
#  extracting: train/100_020_png.rf.3cf5c76e38182fedb674b4659efd2ad7.jpg
#   inflating: train/100_020_png.rf.3cf5c76e38182fedb674b4659efd2ad7.xml
#  extracting: train/100_020_png.rf.812e33e8adb6f6a75761c0bc3913a6e1.jpg
#   inflating: train/100_020_png.rf.812e33e8adb6f6a75761c0bc3913a6e1.xml
#  extracting: train/100_021_png.rf.46c238a59b7ff46fa458fe0adedd5827.jpg
#   inflating: train/100_021_png.rf.46c238a59b7ff46fa458fe0adedd5827.xml
#  extracting: train/100_021_png.rf.5d1ca005544bac9835b0dc76c0a98540.jpg
#   inflating: train/100_021_png.rf.5d1ca005544bac9835b0dc76c0a98540.xml
#  extracting: train/100_021_png.rf.b2299e4bfa0b3da3030485bf1fe67872.jpg
#   inflating: train/100_021_png.rf.b2299e4bfa0b3da3030485bf1fe67872.xml
#  extracting: train/100_022_png.rf.17540978550d9d23cba2a9999e479406.jpg
#   inflating: train/100_022_png.rf.17540978550d9d23cba2a9999e479406.xml
#  extracting: train/100_022_png.rf.c82c01f7e647eaaa8be2fdd4064e892a.jpg
#   inflating: train/100_022_png.rf.c82c01f7e647eaaa8be2fdd4064e892a.xml
#  extracting: train/100_022_png.rf.f399474151ed04b4742ea97023f1599e.jpg
#   inflating: train/100_022_png.rf.f399474151ed04b4742ea97023f1599e.xml
#  extracting: train/100_023_png.rf.89b49f8cf67b04db6fbf23836dbb1a95.jpg
#   inflating: train/100_023_png.rf.89b49f8cf67b04db6fbf23836dbb1a95.xml
#  extracting: train/100_023_png.rf.8d389f2ae9df1d9a19aeeca3a9deaf5f.jpg
#   inflating: train/100_023_png.rf.8d389f2ae9df1d9a19aeeca3a9deaf5f.xml
#  extracting: train/100_023_png.rf.d7488dda140957d65255baaafbe8b0d4.jpg
#   inflating: train/100_023_png.rf.d7488dda140957d65255baaafbe8b0d4.xml
#  extracting: train/100_024_png.rf.0e346c276a53c6ccffe7876be9527637.jpg
#   inflating: train/100_024_png.rf.0e346c276a53c6ccffe7876be9527637.xml
#  extracting: train/100_024_png.rf.68bc6d2e89d98b9a34096cc1d5db7b1c.jpg
#   inflating: train/100_024_png.rf.68bc6d2e89d98b9a34096cc1d5db7b1c.xml
#  extracting: train/100_024_png.rf.f57a238ebb7e568149a0c76d834307e1.jpg
#   inflating: train/100_024_png.rf.f57a238ebb7e568149a0c76d834307e1.xml
#  extracting: train/100_025_png.rf.1a327a2922c853ffddf486ac78224880.jpg
#   inflating: train/100_025_png.rf.1a327a2922c853ffddf486ac78224880.xml
#  extracting: train/100_025_png.rf.a9187ec65aab44602fa1e4aada8faa4d.jpg
#   inflating: train/100_025_png.rf.a9187ec65aab44602fa1e4aada8faa4d.xml
#  extracting: train/100_025_png.rf.db314403f82d8b062ecf1931b6d59010.jpg
#   inflating: train/100_025_png.rf.db314403f82d8b062ecf1931b6d59010.xml
#  extracting: train/100_026_png.rf.93c8c05c540edf42adf9e0da77582daf.jpg
#   inflating: train/100_026_png.rf.93c8c05c540edf42adf9e0da77582daf.xml
#  extracting: train/100_026_png.rf.e00b313749cc60da5a90b573725250ed.jpg
#   inflating: train/100_026_png.rf.e00b313749cc60da5a90b573725250ed.xml
#  extracting: train/100_026_png.rf.ee1eb90043a4b05f8995d5f84f281124.jpg
#   inflating: train/100_026_png.rf.ee1eb90043a4b05f8995d5f84f281124.xml
#  extracting: train/100_027_png.rf.a0a30d6755d694f7f2b4549456fb863b.jpg
#   inflating: train/100_027_png.rf.a0a30d6755d694f7f2b4549456fb863b.xml
#  extracting: train/100_027_png.rf.a757c4fee509414af542fc378a69af34.jpg
#   inflating: train/100_027_png.rf.a757c4fee509414af542fc378a69af34.xml
#  extracting: train/100_027_png.rf.c9ffde3939b8697fcca0e541b529f0f5.jpg
#   inflating: train/100_027_png.rf.c9ffde3939b8697fcca0e541b529f0f5.xml
#  extracting: train/100_029_png.rf.3101236e38bb9face11cde7a3859d558.jpg
#   inflating: train/100_029_png.rf.3101236e38bb9face11cde7a3859d558.xml
#  extracting: train/100_029_png.rf.d24ce63765e0baad60d2aa501717f874.jpg
#   inflating: train/100_029_png.rf.d24ce63765e0baad60d2aa501717f874.xml
#  extracting: train/100_029_png.rf.f435f08b9fce21ff319ca613a73cd079.jpg
#   inflating: train/100_029_png.rf.f435f08b9fce21ff319ca613a73cd079.xml
#  extracting: train/100_030_png.rf.6dc55cfca3be06e3b1bc2385a689df12.jpg
#   inflating: train/100_030_png.rf.6dc55cfca3be06e3b1bc2385a689df12.xml
#  extracting: train/100_030_png.rf.a260029fa2a2dcd005f542d1602836ea.jpg
#   inflating: train/100_030_png.rf.a260029fa2a2dcd005f542d1602836ea.xml
#  extracting: train/100_030_png.rf.bd789817f26cc2e28b4a4e4803b06262.jpg
#   inflating: train/100_030_png.rf.bd789817f26cc2e28b4a4e4803b06262.xml
#  extracting: train/10_002_png.rf.12edf7e39f247c3ca21dd7b5648afa58.jpg
#   inflating: train/10_002_png.rf.12edf7e39f247c3ca21dd7b5648afa58.xml
#  extracting: train/10_002_png.rf.3d07723ec0fa7338a68164749095dab1.jpg
#   inflating: train/10_002_png.rf.3d07723ec0fa7338a68164749095dab1.xml
#  extracting: train/10_002_png.rf.670fae2348cd52a93c72c326a288e799.jpg
#   inflating: train/10_002_png.rf.670fae2348cd52a93c72c326a288e799.xml
#  extracting: train/10_005_png.rf.2a5e1a31917c24d721e077da4af6fc73.jpg
#   inflating: train/10_005_png.rf.2a5e1a31917c24d721e077da4af6fc73.xml
#  extracting: train/10_005_png.rf.8afb86840143d7133eb1e130e464161a.jpg
#   inflating: train/10_005_png.rf.8afb86840143d7133eb1e130e464161a.xml
#  extracting: train/10_005_png.rf.dbc6a732bac82145d08dc633d9ca46b1.jpg
#   inflating: train/10_005_png.rf.dbc6a732bac82145d08dc633d9ca46b1.xml
#  extracting: train/10_006_png.rf.16db6396f93bc211ab1930c95812f797.jpg
#   inflating: train/10_006_png.rf.16db6396f93bc211ab1930c95812f797.xml
#  extracting: train/10_006_png.rf.2c4d8da2c229d130af667d3dba5754e5.jpg
#   inflating: train/10_006_png.rf.2c4d8da2c229d130af667d3dba5754e5.xml
#  extracting: train/10_006_png.rf.336ca00f95ee0ff8412ba235993c5519.jpg
#   inflating: train/10_006_png.rf.336ca00f95ee0ff8412ba235993c5519.xml
#  extracting: train/10_008_png.rf.33e51e81e28f55a8878756643f940f65.jpg
#   inflating: train/10_008_png.rf.33e51e81e28f55a8878756643f940f65.xml
#  extracting: train/10_008_png.rf.424bc50cd69e6c95cf61cfce76a5ad5e.jpg
#   inflating: train/10_008_png.rf.424bc50cd69e6c95cf61cfce76a5ad5e.xml
#  extracting: train/10_008_png.rf.9a6274090f734db20a36ea91f4b51f36.jpg
#   inflating: train/10_008_png.rf.9a6274090f734db20a36ea91f4b51f36.xml
#  extracting: train/10_009_png.rf.625608cde8bd32688b7588b7a9cc155b.jpg
#   inflating: train/10_009_png.rf.625608cde8bd32688b7588b7a9cc155b.xml
#  extracting: train/10_009_png.rf.be93c8e8ebe6c45d10655a1099b101c9.jpg
#   inflating: train/10_009_png.rf.be93c8e8ebe6c45d10655a1099b101c9.xml
#  extracting: train/10_009_png.rf.ed598256b10d53cf426291e82960ea8b.jpg
#   inflating: train/10_009_png.rf.ed598256b10d53cf426291e82960ea8b.xml
#  extracting: train/10_012_png.rf.59babe61f4b20dff90acc5ade2b27d3c.jpg
#   inflating: train/10_012_png.rf.59babe61f4b20dff90acc5ade2b27d3c.xml
#  extracting: train/10_012_png.rf.7cfcd6faee9395fdb3b91fa85fbf822a.jpg
#   inflating: train/10_012_png.rf.7cfcd6faee9395fdb3b91fa85fbf822a.xml
#  extracting: train/10_012_png.rf.ddf0f0416ece7d3f345d8d45a657c679.jpg
#   inflating: train/10_012_png.rf.ddf0f0416ece7d3f345d8d45a657c679.xml
#  extracting: train/10_013_png.rf.2529ee12cd13a2610f99158f437c1f28.jpg
#   inflating: train/10_013_png.rf.2529ee12cd13a2610f99158f437c1f28.xml
#  extracting: train/10_013_png.rf.34def9b6f3c10496bb46335ef32b40af.jpg
#   inflating: train/10_013_png.rf.34def9b6f3c10496bb46335ef32b40af.xml
#  extracting: train/10_013_png.rf.9291f1909bc5ccb1797e456d215006de.jpg
#   inflating: train/10_013_png.rf.9291f1909bc5ccb1797e456d215006de.xml
#  extracting: train/10_014_png.rf.0507fddc194f854c3552fed67c70a6bc.jpg
#   inflating: train/10_014_png.rf.0507fddc194f854c3552fed67c70a6bc.xml
#  extracting: train/10_014_png.rf.28cc1d127b5c78bbec07258c92f51338.jpg
#   inflating: train/10_014_png.rf.28cc1d127b5c78bbec07258c92f51338.xml
#  extracting: train/10_014_png.rf.e790f8da67ef7fe2c79aae5960596064.jpg
#   inflating: train/10_014_png.rf.e790f8da67ef7fe2c79aae5960596064.xml
#  extracting: train/10_021_png.rf.15b83facf23bbd6438a6908de19a8734.jpg
#   inflating: train/10_021_png.rf.15b83facf23bbd6438a6908de19a8734.xml
#  extracting: train/10_021_png.rf.465e9e1ac813cb8b30849aacadb2c145.jpg
#   inflating: train/10_021_png.rf.465e9e1ac813cb8b30849aacadb2c145.xml
#  extracting: train/10_021_png.rf.ca6bc9f5c02aa9ca55e8fcdf0c18768f.jpg
#   inflating: train/10_021_png.rf.ca6bc9f5c02aa9ca55e8fcdf0c18768f.xml
#  extracting: train/10_023_png.rf.a8ba01285e0252fa1dd50a0e8cd9fa96.jpg
#   inflating: train/10_023_png.rf.a8ba01285e0252fa1dd50a0e8cd9fa96.xml
#  extracting: train/10_023_png.rf.fbc1760a42eb01ea5c0e8733451bb67f.jpg
#   inflating: train/10_023_png.rf.fbc1760a42eb01ea5c0e8733451bb67f.xml
#  extracting: train/10_023_png.rf.fd2f8ac2809bacceed932a9323986a4c.jpg
#   inflating: train/10_023_png.rf.fd2f8ac2809bacceed932a9323986a4c.xml
#  extracting: train/10_024_png.rf.15ff155a6914f6bb6e563e5f1e8c8ab1.jpg
#   inflating: train/10_024_png.rf.15ff155a6914f6bb6e563e5f1e8c8ab1.xml
#  extracting: train/10_024_png.rf.6e3998e395d0173e9cc981bc3336bca2.jpg
#   inflating: train/10_024_png.rf.6e3998e395d0173e9cc981bc3336bca2.xml
#  extracting: train/10_024_png.rf.b87af75452a1afa1bc0fc7bf384351ae.jpg
#   inflating: train/10_024_png.rf.b87af75452a1afa1bc0fc7bf384351ae.xml
#  extracting: train/10_027_png.rf.1dae86a86f63aadc4d88c3d16e9911f7.jpg
#   inflating: train/10_027_png.rf.1dae86a86f63aadc4d88c3d16e9911f7.xml
#  extracting: train/10_027_png.rf.7c3c5e27ccf9b7668c0c2d9f818196e3.jpg
#   inflating: train/10_027_png.rf.7c3c5e27ccf9b7668c0c2d9f818196e3.xml
#  extracting: train/10_027_png.rf.984a11da889c1c848f44f6115daeca0b.jpg
#   inflating: train/10_027_png.rf.984a11da889c1c848f44f6115daeca0b.xml
#  extracting: train/10_028_png.rf.5085d1b7b98681b66c0183fa87ecf6ef.jpg
#   inflating: train/10_028_png.rf.5085d1b7b98681b66c0183fa87ecf6ef.xml
#  extracting: train/10_028_png.rf.9deac6b178f173544b7d79dc34806d5c.jpg
#   inflating: train/10_028_png.rf.9deac6b178f173544b7d79dc34806d5c.xml
#  extracting: train/10_028_png.rf.aef28fa5f9a544b8f1d4e34b13e2396b.jpg
#   inflating: train/10_028_png.rf.aef28fa5f9a544b8f1d4e34b13e2396b.xml
#  extracting: train/10_030_png.rf.4f856cf3da8a1c0b5337f7fc836ccb3f.jpg
#   inflating: train/10_030_png.rf.4f856cf3da8a1c0b5337f7fc836ccb3f.xml
#  extracting: train/10_030_png.rf.c94315778c7c6ed0d165d37d2e4eec4a.jpg
#   inflating: train/10_030_png.rf.c94315778c7c6ed0d165d37d2e4eec4a.xml
#  extracting: train/10_030_png.rf.ceabef994666afe3e0946f86100ad84d.jpg
#   inflating: train/10_030_png.rf.ceabef994666afe3e0946f86100ad84d.xml
#  extracting: train/200_002_png.rf.2d2b79935dea8797a107ebc79ff665d2.jpg
#   inflating: train/200_002_png.rf.2d2b79935dea8797a107ebc79ff665d2.xml
#  extracting: train/200_002_png.rf.78136f5b81182ef861a79d1af1e656d6.jpg
#   inflating: train/200_002_png.rf.78136f5b81182ef861a79d1af1e656d6.xml
#  extracting: train/200_002_png.rf.b87022e74181ba262477dee2a530a20f.jpg
#   inflating: train/200_002_png.rf.b87022e74181ba262477dee2a530a20f.xml
#  extracting: train/200_003_png.rf.7412c0e8053f945a5b47485887ea7d1c.jpg
#   inflating: train/200_003_png.rf.7412c0e8053f945a5b47485887ea7d1c.xml
#  extracting: train/200_003_png.rf.949a55d58aa13147f98c3c1c1c0ca759.jpg
#   inflating: train/200_003_png.rf.949a55d58aa13147f98c3c1c1c0ca759.xml
#  extracting: train/200_003_png.rf.ccbb9b21883086427cdf98253a6bc561.jpg
#   inflating: train/200_003_png.rf.ccbb9b21883086427cdf98253a6bc561.xml
#  extracting: train/200_004_png.rf.7fbc0fdc1e0db417f81cc82ca835f77c.jpg
#   inflating: train/200_004_png.rf.7fbc0fdc1e0db417f81cc82ca835f77c.xml
#  extracting: train/200_004_png.rf.b247affa13eaafa1752371124cc8744d.jpg
#   inflating: train/200_004_png.rf.b247affa13eaafa1752371124cc8744d.xml
#  extracting: train/200_004_png.rf.e8f717c06f4bde33f4b11de33ae61b46.jpg
#   inflating: train/200_004_png.rf.e8f717c06f4bde33f4b11de33ae61b46.xml
#  extracting: train/200_005_png.rf.458ab4a02509c67ec80f91598a7b2cda.jpg
#   inflating: train/200_005_png.rf.458ab4a02509c67ec80f91598a7b2cda.xml
#  extracting: train/200_005_png.rf.65257e483f0f1fd92b2f75de4ab5ddff.jpg
#   inflating: train/200_005_png.rf.65257e483f0f1fd92b2f75de4ab5ddff.xml
#  extracting: train/200_005_png.rf.897222efbbb09bf6f020aca537000b15.jpg
#   inflating: train/200_005_png.rf.897222efbbb09bf6f020aca537000b15.xml
#  extracting: train/200_006_png.rf.4f0fbc9064ca594f5c66242ba1e10540.jpg
#   inflating: train/200_006_png.rf.4f0fbc9064ca594f5c66242ba1e10540.xml
#  extracting: train/200_006_png.rf.ac0a707763e2d21c72022b8f05f5ce51.jpg
#   inflating: train/200_006_png.rf.ac0a707763e2d21c72022b8f05f5ce51.xml
#  extracting: train/200_006_png.rf.d2015fa0a54afa973f52e6e9982426b1.jpg
#   inflating: train/200_006_png.rf.d2015fa0a54afa973f52e6e9982426b1.xml
#  extracting: train/200_007_png.rf.07185e2009eb45db02bbe8114ab09bf3.jpg
#   inflating: train/200_007_png.rf.07185e2009eb45db02bbe8114ab09bf3.xml
#  extracting: train/200_007_png.rf.1461b4ace21fc46fffc2bdce8fbeac35.jpg
#   inflating: train/200_007_png.rf.1461b4ace21fc46fffc2bdce8fbeac35.xml
#  extracting: train/200_007_png.rf.d41f1d0e3f9450da794930efe0be0f67.jpg
#   inflating: train/200_007_png.rf.d41f1d0e3f9450da794930efe0be0f67.xml
#  extracting: train/200_009_png.rf.372b427bf01d9dcd3fe0d594fe270139.jpg
#   inflating: train/200_009_png.rf.372b427bf01d9dcd3fe0d594fe270139.xml
#  extracting: train/200_009_png.rf.3968a1e61577b2cffdd5613774894e08.jpg
#   inflating: train/200_009_png.rf.3968a1e61577b2cffdd5613774894e08.xml
#  extracting: train/200_009_png.rf.71689b3d630a085acdc9c40bdb8bb5a7.jpg
#   inflating: train/200_009_png.rf.71689b3d630a085acdc9c40bdb8bb5a7.xml
#  extracting: train/200_010_png.rf.68399c1364a3311c3e9be520a604635d.jpg
#   inflating: train/200_010_png.rf.68399c1364a3311c3e9be520a604635d.xml
#  extracting: train/200_010_png.rf.a7771d9fb3467ad94a2862d8839ef624.jpg
#   inflating: train/200_010_png.rf.a7771d9fb3467ad94a2862d8839ef624.xml
#  extracting: train/200_010_png.rf.fbb3a0fcec79f98a45433648e30eaf95.jpg
#   inflating: train/200_010_png.rf.fbb3a0fcec79f98a45433648e30eaf95.xml
#  extracting: train/200_011_png.rf.39d504f6cf853e7c681473af3221a0db.jpg
#   inflating: train/200_011_png.rf.39d504f6cf853e7c681473af3221a0db.xml
#  extracting: train/200_011_png.rf.7d87bb755e9d7d4a61a05e769f10af37.jpg
#   inflating: train/200_011_png.rf.7d87bb755e9d7d4a61a05e769f10af37.xml
#  extracting: train/200_011_png.rf.878be1f3c63f0090c5b208ad3a9acf32.jpg
#   inflating: train/200_011_png.rf.878be1f3c63f0090c5b208ad3a9acf32.xml
#  extracting: train/200_012_png.rf.5317790ee91a85d61d0e0c1b85136140.jpg
#   inflating: train/200_012_png.rf.5317790ee91a85d61d0e0c1b85136140.xml
#  extracting: train/200_012_png.rf.6240b8965dc61eaebae1ea90316921fe.jpg
#   inflating: train/200_012_png.rf.6240b8965dc61eaebae1ea90316921fe.xml
#  extracting: train/200_012_png.rf.bee24e50a164bdcc57f002e238250c14.jpg
#   inflating: train/200_012_png.rf.bee24e50a164bdcc57f002e238250c14.xml
#  extracting: train/200_014_png.rf.4ac3fd88b5925d205aa8dcb78766ca91.jpg
#   inflating: train/200_014_png.rf.4ac3fd88b5925d205aa8dcb78766ca91.xml
#  extracting: train/200_014_png.rf.68975fd81d68bdaf4588c64fcf7ece6a.jpg
#   inflating: train/200_014_png.rf.68975fd81d68bdaf4588c64fcf7ece6a.xml
#  extracting: train/200_014_png.rf.e9f25781d26805029d4d20095957b27e.jpg
#   inflating: train/200_014_png.rf.e9f25781d26805029d4d20095957b27e.xml
#  extracting: train/200_015_png.rf.790cd66508dd4fe66d3ae8b79033c8f4.jpg
#   inflating: train/200_015_png.rf.790cd66508dd4fe66d3ae8b79033c8f4.xml
#  extracting: train/200_015_png.rf.7b555adabd160bc3e53383cc37a30a10.jpg
#   inflating: train/200_015_png.rf.7b555adabd160bc3e53383cc37a30a10.xml
#  extracting: train/200_015_png.rf.997d69d907d32248b7dfd46f45ce8ee0.jpg
#   inflating: train/200_015_png.rf.997d69d907d32248b7dfd46f45ce8ee0.xml
#  extracting: train/200_016_png.rf.3c3eb521949ecf4773f6dfc5e32277be.jpg
#   inflating: train/200_016_png.rf.3c3eb521949ecf4773f6dfc5e32277be.xml
#  extracting: train/200_016_png.rf.58ccebb4aa11455d2de1a9fd2560307c.jpg
#   inflating: train/200_016_png.rf.58ccebb4aa11455d2de1a9fd2560307c.xml
#  extracting: train/200_016_png.rf.abc0cb33ec17f5d6eac724e5d61dde81.jpg
#   inflating: train/200_016_png.rf.abc0cb33ec17f5d6eac724e5d61dde81.xml
#  extracting: train/200_017_png.rf.9b6e40f8f7bf101b1071685c3c26cdfb.jpg
#   inflating: train/200_017_png.rf.9b6e40f8f7bf101b1071685c3c26cdfb.xml
#  extracting: train/200_017_png.rf.9c2177f8b190f4bfb109bb4b22f50895.jpg
#   inflating: train/200_017_png.rf.9c2177f8b190f4bfb109bb4b22f50895.xml
#  extracting: train/200_017_png.rf.b50b7c63ea2a121927ed67feea3d11cf.jpg
#   inflating: train/200_017_png.rf.b50b7c63ea2a121927ed67feea3d11cf.xml
#  extracting: train/200_018_png.rf.31fbc0d04b293f4b2ff12d5f77e2fc08.jpg
#   inflating: train/200_018_png.rf.31fbc0d04b293f4b2ff12d5f77e2fc08.xml
#  extracting: train/200_018_png.rf.acc055107bf43f41c809cbbc8ea0fd73.jpg
#   inflating: train/200_018_png.rf.acc055107bf43f41c809cbbc8ea0fd73.xml
#  extracting: train/200_018_png.rf.bbf988586dc7688778f821ef957dcfb3.jpg
#   inflating: train/200_018_png.rf.bbf988586dc7688778f821ef957dcfb3.xml
#  extracting: train/200_019_png.rf.554121db311550c617986b2ab3325774.jpg
#   inflating: train/200_019_png.rf.554121db311550c617986b2ab3325774.xml
#  extracting: train/200_019_png.rf.6ff693af3ac7356d6e48f0a13de07f09.jpg
#   inflating: train/200_019_png.rf.6ff693af3ac7356d6e48f0a13de07f09.xml
#  extracting: train/200_019_png.rf.77c1cae2b4895be8686d5346131f7665.jpg
#   inflating: train/200_019_png.rf.77c1cae2b4895be8686d5346131f7665.xml
#  extracting: train/200_020_png.rf.450e0f0ac1bafda68ed5cd67a9fd7e6d.jpg
#   inflating: train/200_020_png.rf.450e0f0ac1bafda68ed5cd67a9fd7e6d.xml
#  extracting: train/200_020_png.rf.6b428df2fdf586eda5589cdc317be297.jpg
#   inflating: train/200_020_png.rf.6b428df2fdf586eda5589cdc317be297.xml
#  extracting: train/200_020_png.rf.7d647aa62dd0f9ea34707cdec1ac3b07.jpg
#   inflating: train/200_020_png.rf.7d647aa62dd0f9ea34707cdec1ac3b07.xml
#  extracting: train/200_021_png.rf.5a3bb7f0d545651d501b889b4fb9beef.jpg
#   inflating: train/200_021_png.rf.5a3bb7f0d545651d501b889b4fb9beef.xml
#  extracting: train/200_021_png.rf.91aee55ac023d89b2f0ee760ebf00132.jpg
#   inflating: train/200_021_png.rf.91aee55ac023d89b2f0ee760ebf00132.xml
#  extracting: train/200_021_png.rf.de9eaee7f90c205a81cd2196bea29f62.jpg
#   inflating: train/200_021_png.rf.de9eaee7f90c205a81cd2196bea29f62.xml
#  extracting: train/200_024_png.rf.36916f703e86ee750512560ac95c2615.jpg
#   inflating: train/200_024_png.rf.36916f703e86ee750512560ac95c2615.xml
#  extracting: train/200_024_png.rf.3959a7d2fa93facf2edb6fe6885dfc88.jpg
#   inflating: train/200_024_png.rf.3959a7d2fa93facf2edb6fe6885dfc88.xml
#  extracting: train/200_024_png.rf.f7d0146a1525b8a405959456da581eac.jpg
#   inflating: train/200_024_png.rf.f7d0146a1525b8a405959456da581eac.xml
#  extracting: train/200_025_png.rf.18c2dbc70f42201fbcba268fde1fd7dc.jpg
#   inflating: train/200_025_png.rf.18c2dbc70f42201fbcba268fde1fd7dc.xml
#  extracting: train/200_025_png.rf.2b759284897f2efb73beeaf8d29d10cb.jpg
#   inflating: train/200_025_png.rf.2b759284897f2efb73beeaf8d29d10cb.xml
#  extracting: train/200_025_png.rf.3f97382d0a2a7ea138d6704553a79f89.jpg
#   inflating: train/200_025_png.rf.3f97382d0a2a7ea138d6704553a79f89.xml
#  extracting: train/200_026_png.rf.3a9b420d9076b4f1b988bdd2882b45ac.jpg
#   inflating: train/200_026_png.rf.3a9b420d9076b4f1b988bdd2882b45ac.xml
#  extracting: train/200_026_png.rf.584dfa532c0bab96e8eaef6ea68d6eda.jpg
#   inflating: train/200_026_png.rf.584dfa532c0bab96e8eaef6ea68d6eda.xml
#  extracting: train/200_026_png.rf.b51c80c58352d5bf2559c0edf8ca4020.jpg
#   inflating: train/200_026_png.rf.b51c80c58352d5bf2559c0edf8ca4020.xml
#  extracting: train/200_028_png.rf.9f4e7ba52a8f383b63649bd9284154c4.jpg
#   inflating: train/200_028_png.rf.9f4e7ba52a8f383b63649bd9284154c4.xml
#  extracting: train/200_028_png.rf.d7a5e9d9c731a0450de6f1425e20558c.jpg
#   inflating: train/200_028_png.rf.d7a5e9d9c731a0450de6f1425e20558c.xml
#  extracting: train/200_028_png.rf.f50b5a2af3efc4c813d4e8ba19c2b9ee.jpg
#   inflating: train/200_028_png.rf.f50b5a2af3efc4c813d4e8ba19c2b9ee.xml
#  extracting: train/200_029_png.rf.2fbb523ea5ca6af0fb92d2718a627741.jpg
#   inflating: train/200_029_png.rf.2fbb523ea5ca6af0fb92d2718a627741.xml
#  extracting: train/200_029_png.rf.b04249550ad54cdffa644f6c8be08c3a.jpg
#   inflating: train/200_029_png.rf.b04249550ad54cdffa644f6c8be08c3a.xml
#  extracting: train/200_029_png.rf.e85ac742c842a9d360d762b0669d373e.jpg
#   inflating: train/200_029_png.rf.e85ac742c842a9d360d762b0669d373e.xml
#  extracting: train/200_030_png.rf.107922b891052b74b2e8b17a11bb5d36.jpg
#   inflating: train/200_030_png.rf.107922b891052b74b2e8b17a11bb5d36.xml
#  extracting: train/200_030_png.rf.53a92d174837dc241750428681cef879.jpg
#   inflating: train/200_030_png.rf.53a92d174837dc241750428681cef879.xml
#  extracting: train/200_030_png.rf.bd3262885976ff42396075690fb19103.jpg
#   inflating: train/200_030_png.rf.bd3262885976ff42396075690fb19103.xml
#  extracting: train/20_002_png.rf.3aa9ef7641500e40150ca33530654313.jpg
#   inflating: train/20_002_png.rf.3aa9ef7641500e40150ca33530654313.xml
#  extracting: train/20_002_png.rf.6543218f9046da92605738f301cfe4f5.jpg
#   inflating: train/20_002_png.rf.6543218f9046da92605738f301cfe4f5.xml
#  extracting: train/20_002_png.rf.732522a5075d224e2ed577c87bfb2003.jpg
#   inflating: train/20_002_png.rf.732522a5075d224e2ed577c87bfb2003.xml
#  extracting: train/20_004_png.rf.3711bd47dda3f5d3d0fababce4df3617.jpg
#   inflating: train/20_004_png.rf.3711bd47dda3f5d3d0fababce4df3617.xml
#  extracting: train/20_004_png.rf.66be423c9385cc83b0e21e96c39be3d0.jpg
#   inflating: train/20_004_png.rf.66be423c9385cc83b0e21e96c39be3d0.xml
#  extracting: train/20_004_png.rf.c28b7b76a597f9c3336dd45dde73fc57.jpg
#   inflating: train/20_004_png.rf.c28b7b76a597f9c3336dd45dde73fc57.xml
#  extracting: train/20_006_png.rf.513738655bbec05ccdaa07c428ac6463.jpg
#   inflating: train/20_006_png.rf.513738655bbec05ccdaa07c428ac6463.xml
#  extracting: train/20_006_png.rf.747dce4ab468be57a1c1fddf9e818726.jpg
#   inflating: train/20_006_png.rf.747dce4ab468be57a1c1fddf9e818726.xml
#  extracting: train/20_006_png.rf.9674fb21b0f3ec5301d21637a142ead2.jpg
#   inflating: train/20_006_png.rf.9674fb21b0f3ec5301d21637a142ead2.xml
#  extracting: train/20_007_png.rf.4920924c404ff8094db85c09abd4f098.jpg
#   inflating: train/20_007_png.rf.4920924c404ff8094db85c09abd4f098.xml
#  extracting: train/20_007_png.rf.981445608b45b8ca9b471f35bad4506a.jpg
#   inflating: train/20_007_png.rf.981445608b45b8ca9b471f35bad4506a.xml
#  extracting: train/20_007_png.rf.add3b5aa8b800c855325024364c8d947.jpg
#   inflating: train/20_007_png.rf.add3b5aa8b800c855325024364c8d947.xml
#  extracting: train/20_008_png.rf.5be778df32b1f845cf1be0de1d832c7a.jpg
#   inflating: train/20_008_png.rf.5be778df32b1f845cf1be0de1d832c7a.xml
#  extracting: train/20_008_png.rf.a47cf242dc74497ce3c86d9fa0cec082.jpg
#   inflating: train/20_008_png.rf.a47cf242dc74497ce3c86d9fa0cec082.xml
#  extracting: train/20_008_png.rf.f88794fdc59d8f8b1d016ce554f70cb8.jpg
#   inflating: train/20_008_png.rf.f88794fdc59d8f8b1d016ce554f70cb8.xml
#  extracting: train/20_010_png.rf.0c9d78e70f948f029b222ad0d5fa736c.jpg
#   inflating: train/20_010_png.rf.0c9d78e70f948f029b222ad0d5fa736c.xml
#  extracting: train/20_010_png.rf.a7403dd0d7e16f5af02fbe614253307f.jpg
#   inflating: train/20_010_png.rf.a7403dd0d7e16f5af02fbe614253307f.xml
#  extracting: train/20_010_png.rf.c6bb1ed0fe3d43b504f826fdb8a4adac.jpg
#   inflating: train/20_010_png.rf.c6bb1ed0fe3d43b504f826fdb8a4adac.xml
#  extracting: train/20_011_png.rf.5a8a4e0079d97eb62800365c3c615d6f.jpg
#   inflating: train/20_011_png.rf.5a8a4e0079d97eb62800365c3c615d6f.xml
#  extracting: train/20_011_png.rf.c34ff6dd70e6d0fe439bfc127c606da3.jpg
#   inflating: train/20_011_png.rf.c34ff6dd70e6d0fe439bfc127c606da3.xml
#  extracting: train/20_011_png.rf.f981ebed43796fccee20fbcdca4d539e.jpg
#   inflating: train/20_011_png.rf.f981ebed43796fccee20fbcdca4d539e.xml
#  extracting: train/20_012_png.rf.35281a16020df0e9b837368ff0048aef.jpg
#   inflating: train/20_012_png.rf.35281a16020df0e9b837368ff0048aef.xml
#  extracting: train/20_012_png.rf.3588159421b19aefceaa2ceb887d0c3d.jpg
#   inflating: train/20_012_png.rf.3588159421b19aefceaa2ceb887d0c3d.xml
#  extracting: train/20_012_png.rf.f4048a77b27f47bed06d2ccc1a00d43e.jpg
#   inflating: train/20_012_png.rf.f4048a77b27f47bed06d2ccc1a00d43e.xml
#  extracting: train/20_013_png.rf.5ffefef3871153c4329af2aac2437751.jpg
#   inflating: train/20_013_png.rf.5ffefef3871153c4329af2aac2437751.xml
#  extracting: train/20_013_png.rf.638c394eb2859aa70f2a71fea1ad359e.jpg
#   inflating: train/20_013_png.rf.638c394eb2859aa70f2a71fea1ad359e.xml
#  extracting: train/20_013_png.rf.8dcd8e361795b657a8c3a4e0aaebc755.jpg
#   inflating: train/20_013_png.rf.8dcd8e361795b657a8c3a4e0aaebc755.xml
#  extracting: train/20_014_png.rf.30f01ae1619e9ad71f55f67b3d2202f9.jpg
#   inflating: train/20_014_png.rf.30f01ae1619e9ad71f55f67b3d2202f9.xml
#  extracting: train/20_014_png.rf.68047414a3bdd0815ecbbcd779f0542d.jpg
#   inflating: train/20_014_png.rf.68047414a3bdd0815ecbbcd779f0542d.xml
#  extracting: train/20_014_png.rf.c44f5057af3f29de622682d0ebd73155.jpg
#   inflating: train/20_014_png.rf.c44f5057af3f29de622682d0ebd73155.xml
#  extracting: train/20_015_png.rf.3cb1f603f6209f35edd4ed29a3ef6c98.jpg
#   inflating: train/20_015_png.rf.3cb1f603f6209f35edd4ed29a3ef6c98.xml
#  extracting: train/20_015_png.rf.e0537305d24b09f3614e062cd7469688.jpg
#   inflating: train/20_015_png.rf.e0537305d24b09f3614e062cd7469688.xml
#  extracting: train/20_015_png.rf.f1817ef538ec6803b2c26215f9cf89f2.jpg
#   inflating: train/20_015_png.rf.f1817ef538ec6803b2c26215f9cf89f2.xml
#  extracting: train/20_016_png.rf.5a5d6d1f952f75889ac6f30232750776.jpg
#   inflating: train/20_016_png.rf.5a5d6d1f952f75889ac6f30232750776.xml
#  extracting: train/20_016_png.rf.bda58537e57f7941954fc187acc945de.jpg
#   inflating: train/20_016_png.rf.bda58537e57f7941954fc187acc945de.xml
#  extracting: train/20_016_png.rf.fc4bad9a438e197d9c5fa9e07f049b5e.jpg
#   inflating: train/20_016_png.rf.fc4bad9a438e197d9c5fa9e07f049b5e.xml
#  extracting: train/20_017_png.rf.5709cdcf7e8707deb45232797cd34d3b.jpg
#   inflating: train/20_017_png.rf.5709cdcf7e8707deb45232797cd34d3b.xml
#  extracting: train/20_017_png.rf.5fccbb4dbfeff80dbed6d1a3dad0908e.jpg
#   inflating: train/20_017_png.rf.5fccbb4dbfeff80dbed6d1a3dad0908e.xml
#  extracting: train/20_017_png.rf.9e29386fb2ee78d361e71e02d0add069.jpg
#   inflating: train/20_017_png.rf.9e29386fb2ee78d361e71e02d0add069.xml
#  extracting: train/20_018_png.rf.0fcd778d477565fcafe3d62162f91ce8.jpg
#   inflating: train/20_018_png.rf.0fcd778d477565fcafe3d62162f91ce8.xml
#  extracting: train/20_018_png.rf.2b4cc8ee3b6c4391801eb3cbbac58842.jpg
#   inflating: train/20_018_png.rf.2b4cc8ee3b6c4391801eb3cbbac58842.xml
#  extracting: train/20_018_png.rf.6fa38657f16bfe093e917437630386b1.jpg
#   inflating: train/20_018_png.rf.6fa38657f16bfe093e917437630386b1.xml
#  extracting: train/20_019_png.rf.b0dbbb3cee4ab7206fe5fec8ffc660a7.jpg
#   inflating: train/20_019_png.rf.b0dbbb3cee4ab7206fe5fec8ffc660a7.xml
#  extracting: train/20_019_png.rf.b69ccb7bf87e6cd0a0b8c0b42f97b03f.jpg
#   inflating: train/20_019_png.rf.b69ccb7bf87e6cd0a0b8c0b42f97b03f.xml
#  extracting: train/20_019_png.rf.d2c5bde0871169a0582b6cb75bebd218.jpg
#   inflating: train/20_019_png.rf.d2c5bde0871169a0582b6cb75bebd218.xml
#  extracting: train/20_020_png.rf.3c38ad53f51c20080cc7521eb8d5b095.jpg
#   inflating: train/20_020_png.rf.3c38ad53f51c20080cc7521eb8d5b095.xml
#  extracting: train/20_020_png.rf.e651ea8b13bab7e447849b92be5f06c0.jpg
#   inflating: train/20_020_png.rf.e651ea8b13bab7e447849b92be5f06c0.xml
#  extracting: train/20_020_png.rf.f8eb0760f4dd1908d19156f84f73eee5.jpg
#   inflating: train/20_020_png.rf.f8eb0760f4dd1908d19156f84f73eee5.xml
#  extracting: train/20_021_png.rf.03721f2ed4a56e8ba88dec752e51e711.jpg
#   inflating: train/20_021_png.rf.03721f2ed4a56e8ba88dec752e51e711.xml
#  extracting: train/20_021_png.rf.32e18b7f102e09acf429b9fd45f03288.jpg
#   inflating: train/20_021_png.rf.32e18b7f102e09acf429b9fd45f03288.xml
#  extracting: train/20_021_png.rf.b3f0a5425a3618ca2cd3aa205d4b1698.jpg
#   inflating: train/20_021_png.rf.b3f0a5425a3618ca2cd3aa205d4b1698.xml
#  extracting: train/20_022_png.rf.36739e7dac4d351be2d5d5250cfae6fd.jpg
#   inflating: train/20_022_png.rf.36739e7dac4d351be2d5d5250cfae6fd.xml
#  extracting: train/20_022_png.rf.c6bcb32a8cbb77a0371335a163afc505.jpg
#   inflating: train/20_022_png.rf.c6bcb32a8cbb77a0371335a163afc505.xml
#  extracting: train/20_022_png.rf.cf3cb28d62429bbe80530d40d3f3cfba.jpg
#   inflating: train/20_022_png.rf.cf3cb28d62429bbe80530d40d3f3cfba.xml
#  extracting: train/20_023_png.rf.8b1812857b8e33ba971216f24b9d21f1.jpg
#   inflating: train/20_023_png.rf.8b1812857b8e33ba971216f24b9d21f1.xml
#  extracting: train/20_023_png.rf.946a6dffdc866fce5c627275d39fd857.jpg
#   inflating: train/20_023_png.rf.946a6dffdc866fce5c627275d39fd857.xml
#  extracting: train/20_023_png.rf.af64b3c7076a7b0c74a7b45090adcbd1.jpg
#   inflating: train/20_023_png.rf.af64b3c7076a7b0c74a7b45090adcbd1.xml
#  extracting: train/20_025_png.rf.10690f85dac20fad54eaefeab91620c8.jpg
#   inflating: train/20_025_png.rf.10690f85dac20fad54eaefeab91620c8.xml
#  extracting: train/20_025_png.rf.32c8010c801735e32b6bae09525f9dec.jpg
#   inflating: train/20_025_png.rf.32c8010c801735e32b6bae09525f9dec.xml
#  extracting: train/20_025_png.rf.688568a15b417c05c08dab755bf3f417.jpg
#   inflating: train/20_025_png.rf.688568a15b417c05c08dab755bf3f417.xml
#  extracting: train/20_026_png.rf.050e940d78c584b5c9d10edac07bb72e.jpg
#   inflating: train/20_026_png.rf.050e940d78c584b5c9d10edac07bb72e.xml
#  extracting: train/20_026_png.rf.39ce8185a4b3eedf5b2126b8b04854dc.jpg
#   inflating: train/20_026_png.rf.39ce8185a4b3eedf5b2126b8b04854dc.xml
#  extracting: train/20_026_png.rf.85ee421c6a47625a05449b3d84f1dced.jpg
#   inflating: train/20_026_png.rf.85ee421c6a47625a05449b3d84f1dced.xml
#  extracting: train/20_028_png.rf.6e62199a1fac46b2b883150405cc5031.jpg
#   inflating: train/20_028_png.rf.6e62199a1fac46b2b883150405cc5031.xml
#  extracting: train/20_028_png.rf.7316ca7bf0217fe638cbb760fe2a7c12.jpg
#   inflating: train/20_028_png.rf.7316ca7bf0217fe638cbb760fe2a7c12.xml
#  extracting: train/20_028_png.rf.d57cf4a70950fee5a029490301a03851.jpg
#   inflating: train/20_028_png.rf.d57cf4a70950fee5a029490301a03851.xml
#  extracting: train/20_029_png.rf.a7c86364cfb73559a68f41fca6053728.jpg
#   inflating: train/20_029_png.rf.a7c86364cfb73559a68f41fca6053728.xml
#  extracting: train/20_029_png.rf.c1f41952a6da8ba05202baae279746dd.jpg
#   inflating: train/20_029_png.rf.c1f41952a6da8ba05202baae279746dd.xml
#  extracting: train/20_029_png.rf.e46a5569c673893c0de2f48e3d095652.jpg
#   inflating: train/20_029_png.rf.e46a5569c673893c0de2f48e3d095652.xml
#  extracting: train/20_030_png.rf.6126bfa13f285c5ad95dba33f8b707ac.jpg
#   inflating: train/20_030_png.rf.6126bfa13f285c5ad95dba33f8b707ac.xml
#  extracting: train/20_030_png.rf.9d2eea1596f025827fd4a2440cff6826.jpg
#   inflating: train/20_030_png.rf.9d2eea1596f025827fd4a2440cff6826.xml
#  extracting: train/20_030_png.rf.b66ae4e5807243810946abe032c03ef4.jpg
#   inflating: train/20_030_png.rf.b66ae4e5807243810946abe032c03ef4.xml
#  extracting: train/50_001_png.rf.18dbe14995e1af1068e0284e453752fa.jpg
#   inflating: train/50_001_png.rf.18dbe14995e1af1068e0284e453752fa.xml
#  extracting: train/50_001_png.rf.49b83f926fbdde1c5a3463480eafa001.jpg
#   inflating: train/50_001_png.rf.49b83f926fbdde1c5a3463480eafa001.xml
#  extracting: train/50_001_png.rf.d7ea843f39169665d9beb818608486ba.jpg
#   inflating: train/50_001_png.rf.d7ea843f39169665d9beb818608486ba.xml
#  extracting: train/50_002_png.rf.2f36c1ce23048686a0647336c45e95f6.jpg
#   inflating: train/50_002_png.rf.2f36c1ce23048686a0647336c45e95f6.xml
#  extracting: train/50_002_png.rf.e4108288e7e394521c6f1257dbeee79a.jpg
#   inflating: train/50_002_png.rf.e4108288e7e394521c6f1257dbeee79a.xml
#  extracting: train/50_002_png.rf.e8cdec1ee68b7fb0d06bec0618bc4002.jpg
#   inflating: train/50_002_png.rf.e8cdec1ee68b7fb0d06bec0618bc4002.xml
#  extracting: train/50_003_png.rf.104e2045e4aabd12d7b6e6f5f21ddc82.jpg
#   inflating: train/50_003_png.rf.104e2045e4aabd12d7b6e6f5f21ddc82.xml
#  extracting: train/50_003_png.rf.37f5eb9065344f8d4846614894cd36c4.jpg
#   inflating: train/50_003_png.rf.37f5eb9065344f8d4846614894cd36c4.xml
#  extracting: train/50_003_png.rf.6d725fb28695cdc06518754f8d41dfcf.jpg
#   inflating: train/50_003_png.rf.6d725fb28695cdc06518754f8d41dfcf.xml
#  extracting: train/50_004_png.rf.1e31538aaa146497ba8a73061c0cd9c2.jpg
#   inflating: train/50_004_png.rf.1e31538aaa146497ba8a73061c0cd9c2.xml
#  extracting: train/50_004_png.rf.40ee9258b3b14dd4dba59e730dbd141c.jpg
#   inflating: train/50_004_png.rf.40ee9258b3b14dd4dba59e730dbd141c.xml
#  extracting: train/50_004_png.rf.f7a793ab0b6b02a21c55035c696ff739.jpg
#   inflating: train/50_004_png.rf.f7a793ab0b6b02a21c55035c696ff739.xml
#  extracting: train/50_005_png.rf.0f45c21b47e5ba5051e93579dca81cbc.jpg
#   inflating: train/50_005_png.rf.0f45c21b47e5ba5051e93579dca81cbc.xml
#  extracting: train/50_005_png.rf.5b8418477bfe8efa0f94131744a98e66.jpg
#   inflating: train/50_005_png.rf.5b8418477bfe8efa0f94131744a98e66.xml
#  extracting: train/50_005_png.rf.d1d8bc5268a34d96eb41042bd36cb713.jpg
#   inflating: train/50_005_png.rf.d1d8bc5268a34d96eb41042bd36cb713.xml
#  extracting: train/50_006_png.rf.84f1ff8ec69c3091027c3c912c6b1b2f.jpg
#   inflating: train/50_006_png.rf.84f1ff8ec69c3091027c3c912c6b1b2f.xml
#  extracting: train/50_006_png.rf.8ccf267d3b6ac7540bfa30d5a094daac.jpg
#   inflating: train/50_006_png.rf.8ccf267d3b6ac7540bfa30d5a094daac.xml
#  extracting: train/50_006_png.rf.d321d123e8962522dbd9c1343ce63fad.jpg
#   inflating: train/50_006_png.rf.d321d123e8962522dbd9c1343ce63fad.xml
#  extracting: train/50_009_png.rf.3d6056bba3c3599dc15aa0fe048bda85.jpg
#   inflating: train/50_009_png.rf.3d6056bba3c3599dc15aa0fe048bda85.xml
#  extracting: train/50_009_png.rf.987daa3ba9a082a4cc44384ae6a5665a.jpg
#   inflating: train/50_009_png.rf.987daa3ba9a082a4cc44384ae6a5665a.xml
#  extracting: train/50_009_png.rf.d2bb8912ce8d517bb99d375ba8508d52.jpg
#   inflating: train/50_009_png.rf.d2bb8912ce8d517bb99d375ba8508d52.xml
#  extracting: train/50_010_png.rf.023ba3773e7e5da47f7dde197d5e27ab.jpg
#   inflating: train/50_010_png.rf.023ba3773e7e5da47f7dde197d5e27ab.xml
#  extracting: train/50_010_png.rf.b3244b6ed019de3434d9472bc15131ef.jpg
#   inflating: train/50_010_png.rf.b3244b6ed019de3434d9472bc15131ef.xml
#  extracting: train/50_010_png.rf.d040b00e32e4c63418240ff97ed1b1e2.jpg
#   inflating: train/50_010_png.rf.d040b00e32e4c63418240ff97ed1b1e2.xml
#  extracting: train/50_013_png.rf.19dd6d3d5f5c6fd9bd14f920ce51f174.jpg
#   inflating: train/50_013_png.rf.19dd6d3d5f5c6fd9bd14f920ce51f174.xml
#  extracting: train/50_013_png.rf.80e083fb71d82e35af36a1526819f819.jpg
#   inflating: train/50_013_png.rf.80e083fb71d82e35af36a1526819f819.xml
#  extracting: train/50_013_png.rf.a22e3083b067a5161928291e1a8f228a.jpg
#   inflating: train/50_013_png.rf.a22e3083b067a5161928291e1a8f228a.xml
#  extracting: train/50_015_png.rf.a4eade0acd661624c4c08579f0b78de8.jpg
#   inflating: train/50_015_png.rf.a4eade0acd661624c4c08579f0b78de8.xml
#  extracting: train/50_015_png.rf.dcd1f28ca2ba1fd685067021f10952fc.jpg
#   inflating: train/50_015_png.rf.dcd1f28ca2ba1fd685067021f10952fc.xml
#  extracting: train/50_015_png.rf.eb3ee7f8bfa16d8321ca3d355638a519.jpg
#   inflating: train/50_015_png.rf.eb3ee7f8bfa16d8321ca3d355638a519.xml
#  extracting: train/50_016_png.rf.5fc7a8020ec203be94559b1e70a2dd7f.jpg
#   inflating: train/50_016_png.rf.5fc7a8020ec203be94559b1e70a2dd7f.xml
#  extracting: train/50_016_png.rf.6a1b567fe036580f152593adf1037ee6.jpg
#   inflating: train/50_016_png.rf.6a1b567fe036580f152593adf1037ee6.xml
#  extracting: train/50_016_png.rf.7209f159ccda7b425f9f9e2bf225e359.jpg
#   inflating: train/50_016_png.rf.7209f159ccda7b425f9f9e2bf225e359.xml
#  extracting: train/50_017_png.rf.155de70404818d02bf53e11b11daf793.jpg
#   inflating: train/50_017_png.rf.155de70404818d02bf53e11b11daf793.xml
#  extracting: train/50_017_png.rf.5e65bb07088203e2013030c3a03b4cfc.jpg
#   inflating: train/50_017_png.rf.5e65bb07088203e2013030c3a03b4cfc.xml
#  extracting: train/50_017_png.rf.60d9e5cfd44b24905a2ee7caa165898e.jpg
#   inflating: train/50_017_png.rf.60d9e5cfd44b24905a2ee7caa165898e.xml
#  extracting: train/50_018_png.rf.0584ec72ea282ab03fc0e62b82bb3215.jpg
#   inflating: train/50_018_png.rf.0584ec72ea282ab03fc0e62b82bb3215.xml
#  extracting: train/50_018_png.rf.104b8b949e988722eb56552aef808819.jpg
#   inflating: train/50_018_png.rf.104b8b949e988722eb56552aef808819.xml
#  extracting: train/50_018_png.rf.2853947afbaf732bf3a28af8795df5a1.jpg
#   inflating: train/50_018_png.rf.2853947afbaf732bf3a28af8795df5a1.xml
#  extracting: train/50_020_png.rf.4f88637e79b62ef604b2df8a1e467c07.jpg
#   inflating: train/50_020_png.rf.4f88637e79b62ef604b2df8a1e467c07.xml
#  extracting: train/50_020_png.rf.80bbcfbe8fb89ffc76db93f754fa511b.jpg
#   inflating: train/50_020_png.rf.80bbcfbe8fb89ffc76db93f754fa511b.xml
#  extracting: train/50_020_png.rf.b0637a03f99ad693c465b0bf1f8cb18a.jpg
#   inflating: train/50_020_png.rf.b0637a03f99ad693c465b0bf1f8cb18a.xml
#  extracting: train/50_022_png.rf.6a7c9984cf4ec4ec2e2d8d5ba93a533a.jpg
#   inflating: train/50_022_png.rf.6a7c9984cf4ec4ec2e2d8d5ba93a533a.xml
#  extracting: train/50_022_png.rf.9129ca7e2ab3eda42b12abdfdea2289d.jpg
#   inflating: train/50_022_png.rf.9129ca7e2ab3eda42b12abdfdea2289d.xml
#  extracting: train/50_022_png.rf.c3e4e93bce9405dfe5f81782ff7ed2a6.jpg
#   inflating: train/50_022_png.rf.c3e4e93bce9405dfe5f81782ff7ed2a6.xml
#  extracting: train/50_023_png.rf.a17472ad8a40a6d8bfbf92a2ddf9a1d4.jpg
#   inflating: train/50_023_png.rf.a17472ad8a40a6d8bfbf92a2ddf9a1d4.xml
#  extracting: train/50_023_png.rf.b123169d18469efce70b63e71c0693b3.jpg
#   inflating: train/50_023_png.rf.b123169d18469efce70b63e71c0693b3.xml
#  extracting: train/50_023_png.rf.d91eaf487c3c14fdb57b7b05f8c47faa.jpg
#   inflating: train/50_023_png.rf.d91eaf487c3c14fdb57b7b05f8c47faa.xml
#  extracting: train/50_024_png.rf.4a604456fe52af1233e756bc64081ecd.jpg
#   inflating: train/50_024_png.rf.4a604456fe52af1233e756bc64081ecd.xml
#  extracting: train/50_024_png.rf.b29a945dce5773802ad06c936de7140a.jpg
#   inflating: train/50_024_png.rf.b29a945dce5773802ad06c936de7140a.xml
#  extracting: train/50_024_png.rf.d03b93819d366cf9f7188b269850f390.jpg
#   inflating: train/50_024_png.rf.d03b93819d366cf9f7188b269850f390.xml
#  extracting: train/50_025_png.rf.7f6381cebe684e74dc56b873c739cd60.jpg
#   inflating: train/50_025_png.rf.7f6381cebe684e74dc56b873c739cd60.xml
#  extracting: train/50_025_png.rf.ac50795ec804f020aaff17eb2bb72595.jpg
#   inflating: train/50_025_png.rf.ac50795ec804f020aaff17eb2bb72595.xml
#  extracting: train/50_025_png.rf.cd8ccc8fe695a4a7302a414da8bcfb76.jpg
#   inflating: train/50_025_png.rf.cd8ccc8fe695a4a7302a414da8bcfb76.xml
#  extracting: train/50_029_png.rf.26f2582158890cc486f7e61d18a80206.jpg
#   inflating: train/50_029_png.rf.26f2582158890cc486f7e61d18a80206.xml
#  extracting: train/50_029_png.rf.c1861eb20d063706bb1de49e88489deb.jpg
#   inflating: train/50_029_png.rf.c1861eb20d063706bb1de49e88489deb.xml
#  extracting: train/50_029_png.rf.d4e21b1387cf99fc373fc01ac8c9ca4c.jpg
#   inflating: train/50_029_png.rf.d4e21b1387cf99fc373fc01ac8c9ca4c.xml
#  extracting: train/50_030_png.rf.6b6274943a9a85a89073ae18539256e4.jpg
#   inflating: train/50_030_png.rf.6b6274943a9a85a89073ae18539256e4.xml
#  extracting: train/50_030_png.rf.931187b49c49c2ea1cf934fd1416aa8c.jpg
#   inflating: train/50_030_png.rf.931187b49c49c2ea1cf934fd1416aa8c.xml
#  extracting: train/50_030_png.rf.d14e0d50c495d0c8f2c5ce3e6f0e8133.jpg
#   inflating: train/50_030_png.rf.d14e0d50c495d0c8f2c5ce3e6f0e8133.xml
#  extracting: train/5_002_png.rf.770e76f6e5aa510774a45c4c2724d868.jpg
#   inflating: train/5_002_png.rf.770e76f6e5aa510774a45c4c2724d868.xml
#  extracting: train/5_002_png.rf.7b58bd54a31acb15094e71bfbfc36347.jpg
#   inflating: train/5_002_png.rf.7b58bd54a31acb15094e71bfbfc36347.xml
#  extracting: train/5_002_png.rf.ccc8b4c1bfd516707ab810f41fe0160d.jpg
#   inflating: train/5_002_png.rf.ccc8b4c1bfd516707ab810f41fe0160d.xml
#  extracting: train/5_004_png.rf.963b6dbf53ab529559acd908954654ba.jpg
#   inflating: train/5_004_png.rf.963b6dbf53ab529559acd908954654ba.xml
#  extracting: train/5_004_png.rf.a1c7c39b5c6bc73e6cc1cdd61e1d46fd.jpg
#   inflating: train/5_004_png.rf.a1c7c39b5c6bc73e6cc1cdd61e1d46fd.xml
#  extracting: train/5_004_png.rf.dabeb7e3effe06a70156029d25a0a52c.jpg
#   inflating: train/5_004_png.rf.dabeb7e3effe06a70156029d25a0a52c.xml
#  extracting: train/5_005_png.rf.2e9800561b2b7cf075e6d99db11790aa.jpg
#   inflating: train/5_005_png.rf.2e9800561b2b7cf075e6d99db11790aa.xml
#  extracting: train/5_005_png.rf.b18a60215c0e3f3bf9f4ebe566e4e03b.jpg
#   inflating: train/5_005_png.rf.b18a60215c0e3f3bf9f4ebe566e4e03b.xml
#  extracting: train/5_005_png.rf.e248be9f6873022671d1ef2bc3634a7d.jpg
#   inflating: train/5_005_png.rf.e248be9f6873022671d1ef2bc3634a7d.xml
#  extracting: train/5_006_png.rf.16df5f90b1df4f943d0408fdbf9de097.jpg
#   inflating: train/5_006_png.rf.16df5f90b1df4f943d0408fdbf9de097.xml
#  extracting: train/5_006_png.rf.330c7e74ae2daaf77564f8a04502dafa.jpg
#   inflating: train/5_006_png.rf.330c7e74ae2daaf77564f8a04502dafa.xml
#  extracting: train/5_006_png.rf.ff1ac38a999ae68b0e6dcc4403502c3a.jpg
#   inflating: train/5_006_png.rf.ff1ac38a999ae68b0e6dcc4403502c3a.xml
#  extracting: train/5_007_png.rf.6179b517706b6e42a2fd1f709a5fcc7b.jpg
#   inflating: train/5_007_png.rf.6179b517706b6e42a2fd1f709a5fcc7b.xml
#  extracting: train/5_007_png.rf.65df0a61c7964af65a4268cc81d87d3a.jpg
#   inflating: train/5_007_png.rf.65df0a61c7964af65a4268cc81d87d3a.xml
#  extracting: train/5_007_png.rf.d26a27e343ae35cea16313843c07be63.jpg
#   inflating: train/5_007_png.rf.d26a27e343ae35cea16313843c07be63.xml
#  extracting: train/5_008_png.rf.3c64d3311665f28e02d3a53b694b4284.jpg
#   inflating: train/5_008_png.rf.3c64d3311665f28e02d3a53b694b4284.xml
#  extracting: train/5_008_png.rf.9800ab23018a1b71d652086acf3a0937.jpg
#   inflating: train/5_008_png.rf.9800ab23018a1b71d652086acf3a0937.xml
#  extracting: train/5_008_png.rf.a0ef9e97566446c65744bf1f4776aa6c.jpg
#   inflating: train/5_008_png.rf.a0ef9e97566446c65744bf1f4776aa6c.xml
#  extracting: train/5_010_png.rf.11e49467c891b370365204860549bf8b.jpg
#   inflating: train/5_010_png.rf.11e49467c891b370365204860549bf8b.xml
#  extracting: train/5_010_png.rf.855eba6a0ecc9783447e46606e92961a.jpg
#   inflating: train/5_010_png.rf.855eba6a0ecc9783447e46606e92961a.xml
#  extracting: train/5_010_png.rf.8b302529d22ea0a9e5ed7b112ee9c39d.jpg
#   inflating: train/5_010_png.rf.8b302529d22ea0a9e5ed7b112ee9c39d.xml
#  extracting: train/5_012_png.rf.10f337f782911d3cf0113ad8b2e3ee99.jpg
#   inflating: train/5_012_png.rf.10f337f782911d3cf0113ad8b2e3ee99.xml
#  extracting: train/5_012_png.rf.152337386257a5909b9a2ae4c40d7414.jpg
#   inflating: train/5_012_png.rf.152337386257a5909b9a2ae4c40d7414.xml
#  extracting: train/5_012_png.rf.886fc14ee6a9bc3f2dcb35b8048d5d33.jpg
#   inflating: train/5_012_png.rf.886fc14ee6a9bc3f2dcb35b8048d5d33.xml
#  extracting: train/5_013_png.rf.090c5d53b584327c94236e0cb9b02482.jpg
#   inflating: train/5_013_png.rf.090c5d53b584327c94236e0cb9b02482.xml
#  extracting: train/5_013_png.rf.49c5db95adc29f4dff2df261d8dbc46d.jpg
#   inflating: train/5_013_png.rf.49c5db95adc29f4dff2df261d8dbc46d.xml
#  extracting: train/5_013_png.rf.74f3ddffd2030a2254bba49133712dac.jpg
#   inflating: train/5_013_png.rf.74f3ddffd2030a2254bba49133712dac.xml
#  extracting: train/5_014_png.rf.09ad04925238a620f8ce58514c4205b7.jpg
#   inflating: train/5_014_png.rf.09ad04925238a620f8ce58514c4205b7.xml
#  extracting: train/5_014_png.rf.ac9120ff73cba6c80c47399cf0254315.jpg
#   inflating: train/5_014_png.rf.ac9120ff73cba6c80c47399cf0254315.xml
#  extracting: train/5_014_png.rf.d9bc37db5d38eab8b3baf970b723fce1.jpg
#   inflating: train/5_014_png.rf.d9bc37db5d38eab8b3baf970b723fce1.xml
#  extracting: train/5_016_png.rf.2bc04bb70b5ca62a7e50ec6709b19fc4.jpg
#   inflating: train/5_016_png.rf.2bc04bb70b5ca62a7e50ec6709b19fc4.xml
#  extracting: train/5_016_png.rf.51092ff95e16fbf54c87bcfa75b76e9d.jpg
#   inflating: train/5_016_png.rf.51092ff95e16fbf54c87bcfa75b76e9d.xml
#  extracting: train/5_016_png.rf.8f071740c6e365da18caea3fe71548dd.jpg
#   inflating: train/5_016_png.rf.8f071740c6e365da18caea3fe71548dd.xml
#  extracting: train/5_017_png.rf.1e8c3b78c664eb58d80f3447c34f55fe.jpg
#   inflating: train/5_017_png.rf.1e8c3b78c664eb58d80f3447c34f55fe.xml
#  extracting: train/5_017_png.rf.c728b95ea12f3446225a7eb024ee06cf.jpg
#   inflating: train/5_017_png.rf.c728b95ea12f3446225a7eb024ee06cf.xml
#  extracting: train/5_017_png.rf.e0c66cbee8b52c51467067518f5452aa.jpg
#   inflating: train/5_017_png.rf.e0c66cbee8b52c51467067518f5452aa.xml
#  extracting: train/5_019_png.rf.66f8a0637555ee34a3d992a310914a7a.jpg
#   inflating: train/5_019_png.rf.66f8a0637555ee34a3d992a310914a7a.xml
#  extracting: train/5_019_png.rf.a7657fe6ab49930b817ec18c6ae4a59e.jpg
#   inflating: train/5_019_png.rf.a7657fe6ab49930b817ec18c6ae4a59e.xml
#  extracting: train/5_019_png.rf.ac772671b5a1790c5d58c2df30eed145.jpg
#   inflating: train/5_019_png.rf.ac772671b5a1790c5d58c2df30eed145.xml
#  extracting: train/5_020_png.rf.12e5cc8927e689a9b4ad278cc1cfc70f.jpg
#   inflating: train/5_020_png.rf.12e5cc8927e689a9b4ad278cc1cfc70f.xml
#  extracting: train/5_020_png.rf.155cec5101000f4207d538f04d09e2a6.jpg
#   inflating: train/5_020_png.rf.155cec5101000f4207d538f04d09e2a6.xml
#  extracting: train/5_020_png.rf.c7f26e7b86f34bad232a218c33c2cfc6.jpg
#   inflating: train/5_020_png.rf.c7f26e7b86f34bad232a218c33c2cfc6.xml
#  extracting: train/5_021_png.rf.a4a3864f2bd1bc251c67b470e4b084d4.jpg
#   inflating: train/5_021_png.rf.a4a3864f2bd1bc251c67b470e4b084d4.xml
#  extracting: train/5_021_png.rf.dc90479bba94e411c643caec287135e5.jpg
#   inflating: train/5_021_png.rf.dc90479bba94e411c643caec287135e5.xml
#  extracting: train/5_021_png.rf.ed2c4d11b812a05a38b590cf69829e3e.jpg
#   inflating: train/5_021_png.rf.ed2c4d11b812a05a38b590cf69829e3e.xml
#  extracting: train/5_022_png.rf.52482001b685530b7f40708e34c7473d.jpg
#   inflating: train/5_022_png.rf.52482001b685530b7f40708e34c7473d.xml
#  extracting: train/5_022_png.rf.b0cb7e971baa7712418f5c8bd0e33b48.jpg
#   inflating: train/5_022_png.rf.b0cb7e971baa7712418f5c8bd0e33b48.xml
#  extracting: train/5_022_png.rf.ef3d925b8f28bb884c7b81a5d762b57d.jpg
#   inflating: train/5_022_png.rf.ef3d925b8f28bb884c7b81a5d762b57d.xml
#  extracting: train/5_023_png.rf.78cbdacc885fa9637fa80b7ce9abde20.jpg
#   inflating: train/5_023_png.rf.78cbdacc885fa9637fa80b7ce9abde20.xml
#  extracting: train/5_023_png.rf.9373d191a42291c7fb2404e53139c8ca.jpg
#   inflating: train/5_023_png.rf.9373d191a42291c7fb2404e53139c8ca.xml
#  extracting: train/5_023_png.rf.f3dff5d163e2601ec79c93113910a44c.jpg
#   inflating: train/5_023_png.rf.f3dff5d163e2601ec79c93113910a44c.xml
#  extracting: train/5_024_png.rf.3e7cbbc2a922d0d0504c11fcd8f5910e.jpg
#   inflating: train/5_024_png.rf.3e7cbbc2a922d0d0504c11fcd8f5910e.xml
#  extracting: train/5_024_png.rf.5f264d0d34ab90aabc63699fca259fa7.jpg
#   inflating: train/5_024_png.rf.5f264d0d34ab90aabc63699fca259fa7.xml
#  extracting: train/5_024_png.rf.cb5e032e90842fdf943d1754e48770c4.jpg
#   inflating: train/5_024_png.rf.cb5e032e90842fdf943d1754e48770c4.xml
#  extracting: train/5_025_png.rf.9671401179500d7b1eb6875ef1748860.jpg
#   inflating: train/5_025_png.rf.9671401179500d7b1eb6875ef1748860.xml
#  extracting: train/5_025_png.rf.af380c76d74cab81e299c2a1ddabf6c3.jpg
#   inflating: train/5_025_png.rf.af380c76d74cab81e299c2a1ddabf6c3.xml
#  extracting: train/5_025_png.rf.b88c1fbed449115ee626ce67a115c289.jpg
#   inflating: train/5_025_png.rf.b88c1fbed449115ee626ce67a115c289.xml
#  extracting: train/5_027_png.rf.2c55d2c2bc6678147d854e120495f147.jpg
#   inflating: train/5_027_png.rf.2c55d2c2bc6678147d854e120495f147.xml
#  extracting: train/5_027_png.rf.84717f613b202b2a32d6a1424e97ab82.jpg
#   inflating: train/5_027_png.rf.84717f613b202b2a32d6a1424e97ab82.xml
#  extracting: train/5_027_png.rf.a8f05e528e75b930ebce9ceeb4b98bdb.jpg
#   inflating: train/5_027_png.rf.a8f05e528e75b930ebce9ceeb4b98bdb.xml
#  extracting: train/5_028_png.rf.2c8209a9ae7fc0abc716b51ebb09773c.jpg
#   inflating: train/5_028_png.rf.2c8209a9ae7fc0abc716b51ebb09773c.xml
#  extracting: train/5_028_png.rf.a22e13e54f5fa77a333067261b09a147.jpg
#   inflating: train/5_028_png.rf.a22e13e54f5fa77a333067261b09a147.xml
#  extracting: train/5_028_png.rf.d6a290e55bdeb1f14149ca8b2967ac2c.jpg
#   inflating: train/5_028_png.rf.d6a290e55bdeb1f14149ca8b2967ac2c.xml
#  extracting: train/5_029_png.rf.27ce9a4df591880e91303520b8fd41ab.jpg
#   inflating: train/5_029_png.rf.27ce9a4df591880e91303520b8fd41ab.xml
#  extracting: train/5_029_png.rf.3316c5acd6c3c3b0735ff2c232638589.jpg
#   inflating: train/5_029_png.rf.3316c5acd6c3c3b0735ff2c232638589.xml
#  extracting: train/5_029_png.rf.a7ba3b01540efb635d7b5d4630f12627.jpg
#   inflating: train/5_029_png.rf.a7ba3b01540efb635d7b5d4630f12627.xml
#  extracting: train/5_030_png.rf.2a517680a2d61c1560526e3f6d433eec.jpg
#   inflating: train/5_030_png.rf.2a517680a2d61c1560526e3f6d433eec.xml
#  extracting: train/5_030_png.rf.79d16f2e03a0d738cc96f0cc399091e7.jpg
#   inflating: train/5_030_png.rf.79d16f2e03a0d738cc96f0cc399091e7.xml
#  extracting: train/5_030_png.rf.b61fa992cdff07960140c218127c0360.jpg
#   inflating: train/5_030_png.rf.b61fa992cdff07960140c218127c0360.xml
#    creating: valid/
#  extracting: valid/100_001_png.rf.e948cc3974d7f72cd8501837f15b0367.jpg
#   inflating: valid/100_001_png.rf.e948cc3974d7f72cd8501837f15b0367.xml
#  extracting: valid/100_006_png.rf.b427b622589de39fd9d23c36129412c2.jpg
#   inflating: valid/100_006_png.rf.b427b622589de39fd9d23c36129412c2.xml
#  extracting: valid/100_016_png.rf.95a8e4d94831132192a8c7b6864e5878.jpg
#   inflating: valid/100_016_png.rf.95a8e4d94831132192a8c7b6864e5878.xml
#  extracting: valid/100_019_png.rf.dd125216b3ad9def05b2ceca7519f82b.jpg
#   inflating: valid/100_019_png.rf.dd125216b3ad9def05b2ceca7519f82b.xml
#  extracting: valid/10_001_png.rf.8fdda8bd439fd31dda1be32c1e7469cd.jpg
#   inflating: valid/10_001_png.rf.8fdda8bd439fd31dda1be32c1e7469cd.xml
#  extracting: valid/10_004_png.rf.547fe0cf070a4e23310e99ed973de892.jpg
#   inflating: valid/10_004_png.rf.547fe0cf070a4e23310e99ed973de892.xml
#  extracting: valid/10_007_png.rf.64117492385d4be12ae236fb5ca0aaa0.jpg
#   inflating: valid/10_007_png.rf.64117492385d4be12ae236fb5ca0aaa0.xml
#  extracting: valid/10_010_png.rf.53aa8b9cd8b75bf50eb180f14b6ef984.jpg
#   inflating: valid/10_010_png.rf.53aa8b9cd8b75bf50eb180f14b6ef984.xml
#  extracting: valid/10_011_png.rf.c0c8884877195f15983a147cbc45b4b7.jpg
#   inflating: valid/10_011_png.rf.c0c8884877195f15983a147cbc45b4b7.xml
#  extracting: valid/10_015_png.rf.3cda8697cecaafc184f837e5ab5bc260.jpg
#   inflating: valid/10_015_png.rf.3cda8697cecaafc184f837e5ab5bc260.xml
#  extracting: valid/10_017_png.rf.645d79ef406795810947b40903f49fc8.jpg
#   inflating: valid/10_017_png.rf.645d79ef406795810947b40903f49fc8.xml
#  extracting: valid/10_018_png.rf.3a7eae416397725aecf0c3781b1f05eb.jpg
#   inflating: valid/10_018_png.rf.3a7eae416397725aecf0c3781b1f05eb.xml
#  extracting: valid/10_019_png.rf.8e5343f5849e7cdad0ee36c8684dc7a6.jpg
#   inflating: valid/10_019_png.rf.8e5343f5849e7cdad0ee36c8684dc7a6.xml
#  extracting: valid/10_020_png.rf.26fd03f2bdd89713f13a1be2d5e9c437.jpg
#   inflating: valid/10_020_png.rf.26fd03f2bdd89713f13a1be2d5e9c437.xml
#  extracting: valid/10_025_png.rf.70a14def978be908777c00b85a8b5cb1.jpg
#   inflating: valid/10_025_png.rf.70a14def978be908777c00b85a8b5cb1.xml
#  extracting: valid/10_029_png.rf.98449d4e559c3321c63bfa6959fae545.jpg
#   inflating: valid/10_029_png.rf.98449d4e559c3321c63bfa6959fae545.xml
#  extracting: valid/200_001_png.rf.834c8a9b7ea49600f6c061409db4aa84.jpg
#   inflating: valid/200_001_png.rf.834c8a9b7ea49600f6c061409db4aa84.xml
#  extracting: valid/200_008_png.rf.55e3f339561719dd82e03e0cbab82d60.jpg
#   inflating: valid/200_008_png.rf.55e3f339561719dd82e03e0cbab82d60.xml
#  extracting: valid/200_013_png.rf.07afcd8fbfe99b9b8d2321b6e58f4bc6.jpg
#   inflating: valid/200_013_png.rf.07afcd8fbfe99b9b8d2321b6e58f4bc6.xml
#  extracting: valid/200_023_png.rf.f4a91d8ba7bec381899c6f65ec44274c.jpg
#   inflating: valid/200_023_png.rf.f4a91d8ba7bec381899c6f65ec44274c.xml
#  extracting: valid/20_003_png.rf.284b111e3caa8039747d6fa91fac0298.jpg
#   inflating: valid/20_003_png.rf.284b111e3caa8039747d6fa91fac0298.xml
#  extracting: valid/20_005_png.rf.6ab7f216a7ba129be7ca239cd9c5a6f4.jpg
#   inflating: valid/20_005_png.rf.6ab7f216a7ba129be7ca239cd9c5a6f4.xml
#  extracting: valid/20_009_png.rf.7a31d12cec10381d2961556171687ae7.jpg
#   inflating: valid/20_009_png.rf.7a31d12cec10381d2961556171687ae7.xml
#  extracting: valid/20_024_png.rf.3b13a4207a2d350f3ccc1cbd3c097264.jpg
#   inflating: valid/20_024_png.rf.3b13a4207a2d350f3ccc1cbd3c097264.xml
#  extracting: valid/20_027_png.rf.e9922d4fe8ad839cda97be1d7d1051d4.jpg
#   inflating: valid/20_027_png.rf.e9922d4fe8ad839cda97be1d7d1051d4.xml
#  extracting: valid/50_007_png.rf.da6f10a28f0eb459f4270105a0f22b0a.jpg
#   inflating: valid/50_007_png.rf.da6f10a28f0eb459f4270105a0f22b0a.xml
#  extracting: valid/50_012_png.rf.8882b6e20e19bbcab31729d04422048f.jpg
#   inflating: valid/50_012_png.rf.8882b6e20e19bbcab31729d04422048f.xml
#  extracting: valid/50_014_png.rf.c2225e9a778706c2aba78782f00f8b44.jpg
#   inflating: valid/50_014_png.rf.c2225e9a778706c2aba78782f00f8b44.xml
#  extracting: valid/50_019_png.rf.4c115022d8c72bdd64042ff679215721.jpg
#   inflating: valid/50_019_png.rf.4c115022d8c72bdd64042ff679215721.xml
#  extracting: valid/50_021_png.rf.3831dc394d36522d617900011760603d.jpg
#   inflating: valid/50_021_png.rf.3831dc394d36522d617900011760603d.xml
#  extracting: valid/50_027_png.rf.a16af0f2553849a0b694a52ddcc8b74f.jpg
#   inflating: valid/50_027_png.rf.a16af0f2553849a0b694a52ddcc8b74f.xml
#  extracting: valid/50_028_png.rf.02dab1de7e65c23df9c277d4a9613462.jpg
#   inflating: valid/50_028_png.rf.02dab1de7e65c23df9c277d4a9613462.xml
#  extracting: valid/5_003_png.rf.2f6c0b551acd2285c19302a79aa265fe.jpg
#   inflating: valid/5_003_png.rf.2f6c0b551acd2285c19302a79aa265fe.xml
#  extracting: valid/5_009_png.rf.663c1308e0ed3268c4a5fb84bf0b677d.jpg
#   inflating: valid/5_009_png.rf.663c1308e0ed3268c4a5fb84bf0b677d.xml
#  extracting: valid/5_011_png.rf.5f9d282079db63eb989f3e0e91629599.jpg
#   inflating: valid/5_011_png.rf.5f9d282079db63eb989f3e0e91629599.xml
#  extracting: valid/5_018_png.rf.e653b37bb85b1939cd8e00968b4dc0ad.jpg
#   inflating: valid/5_018_png.rf.e653b37bb85b1939cd8e00968b4dc0ad.xml

# %%
# %%bash
# cat <<EOF >> /content/labelmap.txt
# 100_TL
# 10_TL
# 200_TL
# 20_TL
# 50_TL
# 5_TL
# EOF

# %% [markdown]
# Download and run the data conversion scripts from the [GitHub repository](https://github.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi) by clicking play on the following three sections of code. They will create TFRecord files for the train and validation datasets, as well as a `labelmap.pbtxt` file which contains the labelmap in a different format.

# %%
# Download data conversion scripts
! wget https://raw.githubusercontent.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/master/util_scripts/create_csv.py
! wget https://raw.githubusercontent.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/master/util_scripts/create_tfrecord.py

# %%
# Create CSV data files and TFRecord files
# !python3 create_csv.py
# !python3 create_tfrecord.py --csv_input=images/train_labels.csv --labelmap=labelmap.txt --image_dir=images/train --output_path=train.tfrecord
# !python3 create_tfrecord.py --csv_input=images/validation_labels.csv --labelmap=labelmap.txt --image_dir=images/validation --output_path=val.tfrecord

# %% [markdown]
# We'll store the locations of the TFRecord and labelmap files as variables so we can reference them later in this Colab session.

# %%
train_record_fname = '/content/train.tfrecord'
val_record_fname = '/content/val.tfrecord'
label_map_pbtxt_fname = '/content/labelmap.pbtxt'

# %% [markdown]
# # 4.&nbsp;Set Up Training Configuration

# %% [markdown]
# In this section, we'll set up the model and training configuration. We'll specifiy which pretrained TensorFlow model we want to use from the [TensorFlow 2 Object Detection Model Zoo](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2_detection_zoo.md). Each model also comes with a configuration file that points to file locations, sets training parameters (such as learning rate and total number of training steps), and more. We'll modify the configuration file for our custom training job.
#
# The first section of code lists out some models availabe in the TF2 Model Zoo and defines some filenames that will be used later to download the model and config file. This makes it easy to manage which model you're using and to add other models to the list later.
#
# Set the "chosen_model" variable to match the name of the model you'd like to train with. It's currently set to use the popular "ssd-mobilenet-v2" model. Click play on the next block once the chosen model has been set.
#
# Not sure which model to pick? [Check out my blog post comparing each model's speed and accuracy.](https://ejtech.io/learn/tflite-object-detection-model-comparison)

# %%
# Change the chosen_model variable to deploy different models available in the TF2 object detection zoo
chosen_model = 'ssd-mobilenet-v2-fpnlite-320'

MODELS_CONFIG = {
    'ssd-mobilenet-v2': {
        'model_name': 'ssd_mobilenet_v2_320x320_coco17_tpu-8',
        'base_pipeline_file': 'ssd_mobilenet_v2_320x320_coco17_tpu-8.config',
        'pretrained_checkpoint': 'ssd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz',
    },
    'efficientdet-d0': {
        'model_name': 'efficientdet_d0_coco17_tpu-32',
        'base_pipeline_file': 'ssd_efficientdet_d0_512x512_coco17_tpu-8.config',
        'pretrained_checkpoint': 'efficientdet_d0_coco17_tpu-32.tar.gz',
    },
    'ssd-mobilenet-v2-fpnlite-320': {
        'model_name': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8',
        'base_pipeline_file': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config',
        'pretrained_checkpoint': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz',
    },
    # The centernet model isn't working as of 9/10/22
    #'centernet-mobilenet-v2': {
    #    'model_name': 'centernet_mobilenetv2fpn_512x512_coco17_od',
    #    'base_pipeline_file': 'pipeline.config',
    #    'pretrained_checkpoint': 'centernet_mobilenetv2fpn_512x512_coco17_od.tar.gz',
    #}
}

model_name = MODELS_CONFIG[chosen_model]['model_name']
pretrained_checkpoint = MODELS_CONFIG[chosen_model]['pretrained_checkpoint']
base_pipeline_file = MODELS_CONFIG[chosen_model]['base_pipeline_file']

# %% [markdown]
# Download the pretrained model file and configuration file by clicking Play on the following section.

# %%
# Create "mymodel" folder for holding pre-trained weights and configuration files
# %mkdir /content/models/mymodel/
# %cd /content/models/mymodel/

# Download pre-trained model weights
import tarfile
download_tar = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/' + pretrained_checkpoint
# !wget {download_tar}
tar = tarfile.open(pretrained_checkpoint)
tar.extractall()
tar.close()

# Download training configuration file for model
download_config = 'https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/' + base_pipeline_file
# !wget {download_config}

# %% [markdown]
# Now that we've downloaded our model and config file, we need to modify the configuration file with some high-level training parameters. The following variables are used to control training steps:
#
# * **num_steps**: The total amount of steps to use for training the model. A good number to start with is 40,000 steps. You can use more steps if you notice the loss metrics are still decreasing by the time training finishes. The more steps, the longer training will take. Training can also be stopped early if loss flattens out before reaching the specified number of steps.
# * **batch_size**: The number of images to use per training step. A larger batch size allows a model to be trained in fewer steps, but the size is limited by the GPU memory available for training. With the GPUs used in Colab instances, 16 is a good number for SSD models and 4 is good for EfficientDet models.
#
# Other training information, like the location of the pretrained model file, the config file, and total number of classes are also assigned in this step. To learn more about training configuration with the TensorFlow Object Detection API, read this [article from Neptune](https://neptune.ai/blog/tensorflow-object-detection-api-best-practices-to-training-evaluation-deployment).

# %%
# Set training parameters for the model
num_steps = 40000

if chosen_model == 'efficientdet-d0':
  batch_size = 4
else:
  batch_size = 16

# %%
# Set file locations and get number of classes for config file
pipeline_fname = '/content/models/mymodel/' + base_pipeline_file
fine_tune_checkpoint = '/content/models/mymodel/' + model_name + '/checkpoint/ckpt-0'

def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())
num_classes = get_num_classes(label_map_pbtxt_fname)
print('Total classes:', num_classes)

# %% [markdown]
# Next, we'll rewrite the config file to use the training parameters we just specified. The following section of code will automatically replace the necessary parameters in the downloaded .config file and save it as our custom "pipeline_file.config" file.

# %%
# Create custom configuration file by writing the dataset, model checkpoint, and training parameters into the base pipeline file
import re

# %cd /content/models/mymodel
print('writing custom configuration file')

with open(pipeline_fname) as f:
    s = f.read()
with open('pipeline_file.config', 'w') as f:

    # Set fine_tune_checkpoint path
    s = re.sub('fine_tune_checkpoint: ".*?"',
               'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), s)

    # Set tfrecord files for train and test datasets
    s = re.sub(
        '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/train)(.*?")', 'input_path: "{}"'.format(train_record_fname), s)
    s = re.sub(
        '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/val)(.*?")', 'input_path: "{}"'.format(val_record_fname), s)

    # Set label_map_path
    s = re.sub(
        'label_map_path: ".*?"', 'label_map_path: "{}"'.format(label_map_pbtxt_fname), s)

    # Set batch_size
    s = re.sub('batch_size: [0-9]+',
               'batch_size: {}'.format(batch_size), s)

    # Set training steps, num_steps
    s = re.sub('num_steps: [0-9]+',
               'num_steps: {}'.format(num_steps), s)

    # Set number of classes num_classes
    s = re.sub('num_classes: [0-9]+',
               'num_classes: {}'.format(num_classes), s)

    # Change fine-tune checkpoint type from "classification" to "detection"
    s = re.sub(
        'fine_tune_checkpoint_type: "classification"', 'fine_tune_checkpoint_type: "{}"'.format('detection'), s)

    # If using ssd-mobilenet-v2, reduce learning rate (because it's too high in the default config file)
    if chosen_model == 'ssd-mobilenet-v2':
      s = re.sub('learning_rate_base: .8',
                 'learning_rate_base: .08', s)

      s = re.sub('warmup_learning_rate: 0.13333',
                 'warmup_learning_rate: .026666', s)

    # If using efficientdet-d0, use fixed_shape_resizer instead of keep_aspect_ratio_resizer (because it isn't supported by TFLite)
    if chosen_model == 'efficientdet-d0':
      s = re.sub('keep_aspect_ratio_resizer', 'fixed_shape_resizer', s)
      s = re.sub('pad_to_max_dimension: true', '', s)
      s = re.sub('min_dimension', 'height', s)
      s = re.sub('max_dimension', 'width', s)

    f.write(s)

# %% [markdown]
# (Optional) If you're curious, you can display the configuration file's contents here in the browser by running the line of code below.

# %%
# (Optional) Display the custom configuration file's contents
# !cat /content/models/mymodel/pipeline_file.config

# %% [markdown]
# Finally, let's set the locations of the configuration file and model output directory as variables so we can reference them when we call the training command.

# %%
# Set the path to the custom config file and the directory to store training checkpoints in
pipeline_file = '/content/models/mymodel/pipeline_file.config'
model_dir = '/content/training/'

# %% [markdown]
# # 5.&nbsp;Train Custom TFLite Detection Model

# %% [markdown]
# We're ready to train our object detection model! Before we start training, let's load up a TensorBoard session to monitor training progress. Run the following section of code, and a TensorBoard session will appear in the browser. It won't show anything yet, because we haven't started training. Once training starts, come back and click the refresh button to see the model's overall loss.

# %%
# %load_ext tensorboard
# %tensorboard --logdir '/content/training/train'

# %% [markdown]
# Model training is performed using the "model_main_tf2.py" script from the TF Object Detection API. Training will take anywhere from 2 to 6 hours, depending on the model, batch size, and number of training steps. We've already defined all the parameters and arguments used by `model_main_tf2.py` in previous sections of this Colab. Just click Play on the following block to begin training!
#
#
#
# > *Note: It takes a few minutes for the program to display any training messages, because it only displays logs once every 100 steps. If it seems like nothing is happening, just wait a couple minutes.*

# %%
# Run training!
# !python /content/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path={pipeline_file} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --sample_1_of_n_eval_examples=1

# %% [markdown]
# If you want to stop training early, just click Stop a couple times or right-click on the code block and select "Interrupt Execution". Otherwise, training will stop by itself once it reaches the specified number of training steps.

# %% [markdown]
# # 6.&nbsp;Convert Model to TensorFlow Lite

# %% [markdown]
# Alright! Our model is all trained up and ready to be used for detecting objects. First, we need to export the model graph (a file that contains information about the architecture and weights) to a TensorFlow Lite-compatible format. We'll do this using the `export_tflite_graph_tf2.py` script.

# %%
# Make a directory to store the trained TFLite model
# !mkdir /content/custom_model_lite
output_directory = '/content/custom_model_lite'

# Path to training directory (the conversion script automatically chooses the highest checkpoint file)
last_model_path = '/content/training'

# !python /content/models/research/object_detection/export_tflite_graph_tf2.py \
    --trained_checkpoint_dir {last_model_path} \
    --output_directory {output_directory} \
    --pipeline_config_path {pipeline_file}

# %% [markdown]
# Next, we'll take the exported graph and use the `TFLiteConverter` module to convert it to `.tflite` FlatBuffer format.

# %%
# Convert exported graph file into TFLite model file
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_saved_model('/content/custom_model_lite/saved_model')
tflite_model = converter.convert()

with open('/content/custom_model_lite/detect.tflite', 'wb') as f:
  f.write(tflite_model)

# %% [markdown]
# # 7.&nbsp;Test TensorFlow Lite Model and Calculate mAP

# %% [markdown]
# We've trained our custom model and converted it to TFLite format. But how well does it actually perform at detecting objects in images? This is where the images we set aside in the **test** folder come in. The model never saw any test images during training, so its performance on these images should be representative of how it will perform on new images from the field.
#
# ### 7.1 Inference test images
# The following code defines a function to run inference on test images. It loads the images, loads the model and labelmap, runs the model on each image, and displays the result. It also optionally saves detection results as text files so we can use them to calculate model mAP score.
#
# This code is based off the [TFLite_detection_image.py](https://github.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/blob/master/TFLite_detection_image.py) script from my [TensorFlow Lite Object Detection repository on GitHub](https://github.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi); feel free to use it as a starting point for your own application.

# %%
# Script to run custom TFLite model on test images to detect objects
# Source: https://github.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/blob/master/TFLite_detection_image.py

# Import packages
import os
import cv2
import numpy as np
import sys
import glob
import random
import importlib.util
from tensorflow.lite.python.interpreter import Interpreter

import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

### Define function for inferencing with TFLite model and displaying results

def tflite_detect_images(modelpath, imgpath, lblpath, min_conf=0.5, num_test_images=10, savepath='/content/results', txt_only=False):

  # Grab filenames of all images in test folder
  images = glob.glob(imgpath + '/*.jpg') + glob.glob(imgpath + '/*.JPG') + glob.glob(imgpath + '/*.png') + glob.glob(imgpath + '/*.bmp')

  # Load the label map into memory
  with open(lblpath, 'r') as f:
      labels = [line.strip() for line in f.readlines()]

  # Load the Tensorflow Lite model into memory
  interpreter = Interpreter(model_path=modelpath)
  interpreter.allocate_tensors()

  # Get model details
  input_details = interpreter.get_input_details()
  output_details = interpreter.get_output_details()
  height = input_details[0]['shape'][1]
  width = input_details[0]['shape'][2]

  float_input = (input_details[0]['dtype'] == np.float32)

  input_mean = 127.5
  input_std = 127.5

  # Randomly select test images
  images_to_test = random.sample(images, num_test_images)

  # Loop over every image and perform detection
  for image_path in images_to_test:

      # Load image and resize to expected shape [1xHxWx3]
      image = cv2.imread(image_path)
      image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
      imH, imW, _ = image.shape
      image_resized = cv2.resize(image_rgb, (width, height))
      input_data = np.expand_dims(image_resized, axis=0)

      # Normalize pixel values if using a floating model (i.e. if model is non-quantized)
      if float_input:
          input_data = (np.float32(input_data) - input_mean) / input_std

      # Perform the actual detection by running the model with the image as input
      interpreter.set_tensor(input_details[0]['index'],input_data)
      interpreter.invoke()

      # Retrieve detection results
      boxes = interpreter.get_tensor(output_details[1]['index'])[0] # Bounding box coordinates of detected objects
      classes = interpreter.get_tensor(output_details[3]['index'])[0] # Class index of detected objects
      scores = interpreter.get_tensor(output_details[0]['index'])[0] # Confidence of detected objects

      detections = []

      # Loop over all detections and draw detection box if confidence is above minimum threshold
      for i in range(len(scores)):
          if ((scores[i] > min_conf) and (scores[i] <= 1.0)):

              # Get bounding box coordinates and draw box
              # Interpreter can return coordinates that are outside of image dimensions, need to force them to be within image using max() and min()
              ymin = int(max(1,(boxes[i][0] * imH)))
              xmin = int(max(1,(boxes[i][1] * imW)))
              ymax = int(min(imH,(boxes[i][2] * imH)))
              xmax = int(min(imW,(boxes[i][3] * imW)))

              cv2.rectangle(image, (xmin,ymin), (xmax,ymax), (10, 255, 0), 2)

              # Draw label
              object_name = labels[int(classes[i])] # Look up object name from "labels" array using class index
              label = '%s: %d%%' % (object_name, int(scores[i]*100)) # Example: 'person: 72%'
              labelSize, baseLine = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.7, 2) # Get font size
              label_ymin = max(ymin, labelSize[1] + 10) # Make sure not to draw label too close to top of window
              cv2.rectangle(image, (xmin, label_ymin-labelSize[1]-10), (xmin+labelSize[0], label_ymin+baseLine-10), (255, 255, 255), cv2.FILLED) # Draw white box to put label text in
              cv2.putText(image, label, (xmin, label_ymin-7), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 0), 2) # Draw label text

              detections.append([object_name, scores[i], xmin, ymin, xmax, ymax])


      # All the results have been drawn on the image, now display the image
      if txt_only == False: # "text_only" controls whether we want to display the image results or just save them in .txt files
        image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
        plt.figure(figsize=(12,16))
        plt.imshow(image)
        plt.show()

      # Save detection results in .txt files (for calculating mAP)
      elif txt_only == True:

        # Get filenames and paths
        image_fn = os.path.basename(image_path)
        base_fn, ext = os.path.splitext(image_fn)
        txt_result_fn = base_fn +'.txt'
        txt_savepath = os.path.join(savepath, txt_result_fn)

        # Write results to text file
        # (Using format defined by https://github.com/Cartucho/mAP, which will make it easy to calculate mAP)
        with open(txt_savepath,'w') as f:
            for detection in detections:
                f.write('%s %.4f %d %d %d %d\n' % (detection[0], detection[1], detection[2], detection[3], detection[4], detection[5]))

  return

# %% [markdown]
# The next block sets the paths to the test images and models and then runs the inferencing function. If you want to use more than 10 images, change the `images_to_test` variable. Click play to run inferencing!

# %%
# Set up variables for running user's model
PATH_TO_IMAGES='/content/images/test'   # Path to test images folder
PATH_TO_MODEL='/content/custom_model_lite/detect.tflite'   # Path to .tflite model file
PATH_TO_LABELS='/content/labelmap.txt'   # Path to labelmap.txt file
min_conf_threshold=0.5   # Confidence threshold (try changing this to 0.01 if you don't see any detection results)
images_to_test = 10   # Number of images to run detection on

# Run inferencing function!
tflite_detect_images(PATH_TO_MODEL, PATH_TO_IMAGES, PATH_TO_LABELS, min_conf_threshold, images_to_test)

# %% [markdown]
# ### 7.2 Calculate mAP
# Now we have a visual sense of how our model performs on test images, but how can we quantitatively measure its accuracy?
#
# One popular methord for measuring object detection model accuracy is "mean average precision" (mAP). Basically, the higher the mAP score, the better your model is at detecting objects in images. To learn more about mAP, read through this [article from Roboflow](https://blog.roboflow.com/mean-average-precision/).
#
# We'll use the mAP calculator tool at https://github.com/Cartucho/mAP to determine our model's mAP score. First, we need to clone the repository and remove its existing example data. We'll also download a script I wrote for interfacing with the calculator.

# %%
# %%bash
# git clone https://github.com/Cartucho/mAP /content/mAP
# cd /content/mAP
# rm input/detection-results/*
# rm input/ground-truth/*
# rm input/images-optional/*
# wget https://raw.githubusercontent.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/master/util_scripts/calculate_map_cartucho.py

# %% [markdown]
# Next, we'll copy the images and annotation data from the **test** folder to the appropriate folders inside the cloned repository. These will be used as the "ground truth data" that our model's detection results will be compared to.

# %%
# !cp /content/images/test/* /content/mAP/input/images-optional # Copy images and xml files
# !mv /content/mAP/input/images-optional/*.xml /content/mAP/input/ground-truth/  # Move xml files to the appropriate folder

# %% [markdown]
# The calculator tool expects annotation data in a format that's different from the Pascal VOC .xml file format we're using. Fortunately, it provides an easy script, `convert_gt_xml.py`, for converting to the expected .txt format.

# %%
# !python /content/mAP/scripts/extra/convert_gt_xml.py

# %% [markdown]
# Okay, we've set up the ground truth data, but now we need actual detection results from our model. The detection results will be compared to the ground truth data to calculate the model's accuracy in mAP.
#
# The inference function we defined in Step 7.1 can be used to generate detection data for all the images in the **test** folder. We'll use it the same as before, except this time we'll tell it to save detection results into the `detection-results` folder.
#
# Click Play to run the following code block!

# %%
# Set up variables for running inference, this time to get detection results saved as .txt files
PATH_TO_IMAGES='/content/images/test'   # Path to test images folder
PATH_TO_MODEL='/content/custom_model_lite/detect.tflite'   # Path to .tflite model file
PATH_TO_LABELS='/content/labelmap.txt'   # Path to labelmap.txt file
PATH_TO_RESULTS='/content/mAP/input/detection-results' # Folder to save detection results in
min_conf_threshold=0.1   # Confidence threshold

# Use all the images in the test folder
image_list = glob.glob(PATH_TO_IMAGES + '/*.jpg') + glob.glob(PATH_TO_IMAGES + '/*.JPG') + glob.glob(PATH_TO_IMAGES + '/*.png') + glob.glob(PATH_TO_IMAGES + '/*.bmp')
images_to_test = min(500, len(image_list)) # If there are more than 500 images in the folder, just use 500

# Tell function to just save results and not display images
txt_only = True

# Run inferencing function!
print('Starting inference on %d images...' % images_to_test)
tflite_detect_images(PATH_TO_MODEL, PATH_TO_IMAGES, PATH_TO_LABELS, min_conf_threshold, images_to_test, PATH_TO_RESULTS, txt_only)
print('Finished inferencing!')

# %% [markdown]
# Finally, let's calculate mAP! One popular style for reporting mAP is the COCO metric for mAP @ 0.50:0.95. Basically, this means that mAP is calculated at several IoU thresholds between 0.50 and 0.95, and then the result from each threshold is averaged to get a final mAP score. [Learn more here!](https://blog.roboflow.com/mean-average-precision/)
#
# I wrote a script to run the calculator tool at each IoU threshold, average the results, and report the final accuracy score. It reports mAP for each class and overall mAP. Click Play on the following two blocks to calculate mAP!

# %%
# %cd /content/mAP
# !python calculate_map_cartucho.py --labels=/content/labelmap.txt

# %% [markdown]
# The score reported at the end is your model's overall mAP score. Ideally, it should be above 50% (0.50). If it isn't, you can increase your model's accuracy by adding more images to your dataset. See my [dataset video](https://www.youtube.com/watch?v=v0ssiOY6cfg) for tips on how to capture good training images and improve accuracy.

# %% [markdown]
# # 8.&nbsp;Deploy TensorFlow Lite Model

# %% [markdown]
# Now that your custom model has been trained and converted to TFLite format, it's ready to be downloaded and deployed in an application! This section shows how to download the model and provides links to instructions for deploying it on the Raspberry Pi, your PC, or other edge devices.

# %% [markdown]
# ## 8.1. Download TFLite model
#
# Run the two following cells to copy the labelmap files into the model folder, compress it into a zip folder, and then download it. The zip folder contains the `detect.tflite` model and `labelmap.txt` labelmap files that are needed to run the model in your application.

# %%
# Move labelmap and pipeline config files into TFLite model folder and zip it up
# !cp /content/labelmap.txt /content/custom_model_lite
# !cp /content/labelmap.pbtxt /content/custom_model_lite
# !cp /content/models/mymodel/pipeline_file.config /content/custom_model_lite

# %cd /content
# !zip -r custom_model_lite.zip custom_model_lite

# %%
from google.colab import files

files.download('/content/custom_model_lite.zip')

# %% [markdown]
# The `custom_model_lite.zip` file containing the model will download into your Downloads folder. It's ready to be deployed on your device!

# %% [markdown]
# ## 8.2. Deploy model
# TensorFlow Lite models can run on a wide variety of hardware, including PCs, embedded systems, and phones. This section provides instructions showing how to deploy your TFLite model on various devices.
#
# ### 8.2.1. Deploy on Raspberry Pi
# TFLite models are great for running on the Raspberry Pi, because they require less processing power than regular TensorFlow vision models. The Pi can run TFLite models in near real-time.
#
# To run your new model on the Raspberry Pi, you'll have to install TensorFlow Lite and prepare a Python environment for your application. I provide step-by-step instructions on how to set up TFLite on the Pi in my video, [How To Run TensorFlow Lite on Raspberry Pi for Object Detection](https://youtu.be/aimSGOAUI8Y).
#
# [![Link to my YouTube video!](https://raw.githubusercontent.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/master/doc/YouTube_video1.JPG)](https://www.youtube.com/watch?v=aimSGOAUI8Y)
#
# Once you've completed all the steps in the video, move the `custom_model_lite.zip` file downloaded from this Colab session over to your Raspberry Pi into the `~/tflite1` folder. Move into the folder and unzip it by issuing:
#
# ```
# cd ~/tflite1
# unzip custom_model_lite.zip
# ```
#
# Then, run the image, video, or webcam TFLite detection program with the `--modeldir=fine_tuned_model_lite` argument. For example, to run the webcam detection program, issue:
#
# ```
# python TFLite_detection_webcam.py --modeldir=custom_model_lite
# ```
#
# A window will appear showing a live feed from your webcam with boxes drawn around detected objects in each frame.
#
# ### 8.2.2. Deploy on Windows, Linux, or macOS
# Follow the instructions linked below to quickly set up your Windows, Linux, or macOS computer to run TFLite models. It only takes a few minutes! Running a model on your PC is good for quickly testing your model with a webcam. However, keep in mind that the TFLite Runtime is optimized for lower-power processors, and it won't utilize the full capability of your PC's processor.
#
# Here are links to the deployment guides for Windows, Linux, and macOS:
# * [How to Run TensorFlow Lite Models on Windows](https://github.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/blob/master/deploy_guides/Windows_TFLite_Guide.md)
# * *link to Linux guide to be added (but really it's the same as Raspberry Pi)*
# * [How to Run TensorFlow Lite Models on macOS](https://github.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/blob/master/deploy_guides/MacOS_TFLite_Guide.md)
#
# ### 8.2.3. Deploy on other Linux-based edge devices
# Instructions to be added! 🐧
#
# ### 8.2.4. Deploy on Android
# Instructions to be added! 🤖

# %% [markdown]
# # 9.&nbsp;(Optional) Post-Training Quantization

# %% [markdown]
# Want to make your TFLite model run even faster? Quantize it! Quantizating a model converts its weights from 32-bit floating-point values to 8-bit integer values. This allows the quantized model to run faster and occupy less memory without too much reduction in accuracy.
#
# > Note: If you observe an obvious decrease in detection accuracy when quantizing your model with TF2, I recommend using TensorFlow 1 to quantize your model instead. TF1 supports quantization-aware training, which helps improve the accuracy of quantized models. The ssd-mobilenet-v2-quantized model from the TF1 Model Zoo has fast and accurate performance when trained with a custom dataset. Visit my [TFLite v1 Colab notebook](https://colab.research.google.com/github/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/blob/master/Train_TFLite1_Object_Detection_Model.ipynb) for step-by-step instructions on how to train and quantize a model with TensorFlow 1.

# %% [markdown]
# ## 9.1. Quantize model
# We'll use the "TFLiteConverter" module to perform [post-training quantization](https://www.tensorflow.org/lite/performance/post_training_quantization) on the model. To quantize the model, we need to provide a representative dataset, which is a set of images that represent what the model will see when deployed in the field. First, we'll create a list of images to include in the representative dataset (we'll just use the images in the `train` folder).

# %%
# Get list of all images in train directory
image_path = '/content/images/train'

jpg_file_list = glob.glob(image_path + '/*.jpg')
JPG_file_list = glob.glob(image_path + '/*.JPG')
png_file_list = glob.glob(image_path + '/*.png')
bmp_file_list = glob.glob(image_path + '/*.bmp')

quant_image_list = jpg_file_list + JPG_file_list + png_file_list + bmp_file_list

# %% [markdown]
# Next, we'll define a function to yield images from our representative dataset. Refer to [TensorFlow's sample quantization code](https://colab.research.google.com/github/google-coral/tutorials/blob/master/retrain_classification_ptq_tf2.ipynb#scrollTo=kRDabW_u1wnv) to get a better understanding of what this is doing!

# %%
# A generator that provides a representative dataset
# Code modified from https://colab.research.google.com/github/google-coral/tutorials/blob/master/retrain_classification_ptq_tf2.ipynb

# First, get input details for model so we know how to preprocess images
interpreter = Interpreter(model_path=PATH_TO_MODEL) # PATH_TO_MODEL is defined in Step 7 above
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
height = input_details[0]['shape'][1]
width = input_details[0]['shape'][2]

import random

def representative_data_gen():
  dataset_list = quant_image_list
  quant_num = 300
  for i in range(quant_num):
    pick_me = random.choice(dataset_list)
    image = tf.io.read_file(pick_me)

    if pick_me.endswith('.jpg') or pick_me.endswith('.JPG'):
      image = tf.io.decode_jpeg(image, channels=3)
    elif pick_me.endswith('.png'):
      image = tf.io.decode_png(image, channels=3)
    elif pick_me.endswith('.bmp'):
      image = tf.io.decode_bmp(image, channels=3)

    image = tf.image.resize(image, [width, height])  # TO DO: Replace 300s with an automatic way of reading network input size
    image = tf.cast(image / 255., tf.float32)
    image = tf.expand_dims(image, 0)
    yield [image]

# %% [markdown]
# Finally, we'll initialize the TFLiteConverter module, point it at the TFLite graph we generated in Step 6, and provide it with the representative dataset generator function we created in the previous code block. We'll configure the converter to quantize the model's weight values to INT8 format.

# %%
# Initialize converter module
converter = tf.lite.TFLiteConverter.from_saved_model('/content/custom_model_lite/saved_model')

# This enables quantization
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# This sets the representative dataset for quantization
converter.representative_dataset = representative_data_gen
# This ensures that if any ops can't be quantized, the converter throws an error
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
# For full integer quantization, though supported types defaults to int8 only, we explicitly declare it for clarity.
converter.target_spec.supported_types = [tf.int8]
# These set the input tensors to uint8 and output tensors to float32
converter.inference_input_type = tf.uint8
converter.inference_output_type = tf.float32
tflite_model = converter.convert()

with open('/content/custom_model_lite/detect_quant.tflite', 'wb') as f:
  f.write(tflite_model)

# %% [markdown]
# ## 9.2. Test quantized model
# The model has been quantized and exported as `detect_quant.tflite`. Let's test it out! We'll re-use the function from Section 7 for running the model on test images and display the results, except this time we'll point it at the quantized model.
#
# Click Play on the code block below to test the `detect_quant.tflite` model.

# %%
# Set up parameters for inferencing function (using detect_quant.tflite instead of detect.tflite)
PATH_TO_IMAGES='/content/images/test'   #Path to test images folder
PATH_TO_MODEL='/content/custom_model_lite/detect_quant.tflite'   #Path to .tflite model file
PATH_TO_LABELS='/content/labelmap.txt'   #Path to labelmap.txt file
min_conf_threshold=0.5   #Confidence threshold (try changing this to 0.01 if you don't see any detection results)
images_to_test = 10   #Number of images to run detection on

# Run inferencing function!
tflite_detect_images(PATH_TO_MODEL, PATH_TO_IMAGES, PATH_TO_LABELS, min_conf_threshold, images_to_test)

# %% [markdown]
# If your quantized model isn't performing very well, try using my TensorFlow Lite 1 notebook *(link to be added)* to train a SSD-MobileNet model with your dataset. In my experience, the `ssd-mobilenet-v2-quantized` model from the [TF1 Model Zoo](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf1_detection_zoo.md) has the best quantized performance out of any other TensorFlow Lite model.
#
# TFLite models created with TensorFlow 1 are still compatible with the TensorFlow Lite 2 runtime, so your TFLite 1 model will still work with my [TensorFlow setup guide for the Raspberry Pi](https://github.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/blob/master/Raspberry_Pi_Guide.md).

# %% [markdown]
# ## 9.3 Calculate quantized model mAP
#
# Let's calculate the quantize model's mAP using the calculator tool we set up in Step 7.2. We just need to perform inference with our quantized model (`detect_quant.tflite`) to get a new set of detection results.
#
# Run the following block to run inference on the test images and save the detection results.

# %%
# Need to remove existing detection results first
# !rm /content/mAP/input/detection-results/*

# Set up variables for running inference, this time to get detection results saved as .txt files
PATH_TO_IMAGES='/content/images/test'   # Path to test images folder
PATH_TO_MODEL='/content/custom_model_lite/detect_quant.tflite'   # Path to quantized .tflite model file
PATH_TO_LABELS='/content/labelmap.txt'   # Path to labelmap.txt file
PATH_TO_RESULTS='/content/mAP/input/detection-results' # Folder to save detection results in
min_conf_threshold=0.1   # Confidence threshold

# Use all the images in the test folder
image_list = glob.glob(PATH_TO_IMAGES + '/*.jpg') + glob.glob(PATH_TO_IMAGES + '/*.JPG') + glob.glob(PATH_TO_IMAGES + '/*.png') + glob.glob(PATH_TO_IMAGES + '/*.bmp')
images_to_test = min(500, len(image_list)) # If there are more than 500 images in the folder, just use 500

# Tell function to just save results and not display images
txt_only = True

# Run inferencing function!
print('Starting inference on %d images...' % images_to_test)
tflite_detect_images(PATH_TO_MODEL, PATH_TO_IMAGES, PATH_TO_LABELS, min_conf_threshold, images_to_test, PATH_TO_RESULTS, txt_only)
print('Finished inferencing!')

# %% [markdown]
# Now we can run the mAP calculation script to determine our quantized model's mAP.

# %%
cd /content/mAP

# %%
# !python calculate_map_cartucho.py --labels=/content/labelmap.txt

# %% [markdown]
# ## 9.4. Compile model for Edge TPU
#
# Now that the model has been converted to TFLite and quantized, we can compile it to run on Edge TPU devices like the [Coral USB Accelerator](https://coral.ai/products/accelerator/) or the [Coral Dev Board](https://coral.ai/products/dev-board/). This allows the model to run much faster! For information on how to set up the USB Accelerator, my [TensorFlow Lite repository on GitHub](https://github.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/blob/master/deploy_guides/Raspberry_Pi_Guide.md#section-2---run-edge-tpu-object-detection-models-on-the-raspberry-pi-using-the-coral-usb-accelerator).
#
# First, install the Edge TPU Compiler package inside this Colab instance.

# %%
! curl https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo apt-key add -
! echo "deb https://packages.cloud.google.com/apt coral-edgetpu-stable main" | sudo tee /etc/apt/sources.list.d/coral-edgetpu.list
! sudo apt-get update
! sudo apt-get install edgetpu-compiler

# %% [markdown]
# Next, compile the quantize TFLite model. (If your model has a different filename than "detect_quant.tflite", use that instead.)

# %%
# %cd /content/custom_model_lite
# !edgetpu_compiler detect_quant.tflite
# !mv detect_quant_edgetpu.tflite edgetpu.tflite
# !rm detect_quant_edgetpu.log

# %% [markdown]
# The compiled model will be output in the `custom_model_lite` folder as "detect__quant_edgetpu.tflite". It gets renamed to "edgetpu.tflite" to be consistent with my code. Zip the `custom_model_lite` folder and download it by running the two code blocks below.

# %%
# %cd /content
# !zip -r custom_model_lite.zip custom_model_lite

# %%
from google.colab import files

files.download('custom_model_lite.zip')

# %% [markdown]
# Now you're all set to use the Coral model! For instructions on how to run an object detection model on the Raspberry Pi using the Coral USB Acclerator, please see my video, ["How to Use the Coral USB Accelerator with the Raspberry Pi"](https://www.youtube.com/watch?v=qJMwNHQNOVU).

# %% [markdown]
# # Appendix: Common Errors

# %% [markdown]
# Here are solutions to common errors that can occur while stepping through this notebook.
#
# **1. Training suddenly stops with ^C output**
#
# If your training randomly stops without any error messages except a `^C`, that means the virtual machine has run out of memory. To resolve the issue, try reducing the `batch_size` variable in Step 4 to a lower value like `batch_size = 4`. The value must be a power of 2. (e.g. 2, 4, 8 ...)
#
# Source: https://stackoverflow.com/questions/75901898/why-my-model-training-automatically-stopped-during-training
